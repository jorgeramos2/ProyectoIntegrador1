# %%
import nltk

# %%
# nltk.download()

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
example_text = 'Hello Mr. Smith, how are you doing today? The weather is great and Python is awesome. The sky is pinkish-blue. You should not eat cardboard.'
print(sent_tokenize(example_text))
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great and Python is awesome.', 'The sky is pinkish-blue.', 'You should not eat cardboard.']

# %%
print(word_tokenize(example_text))
# Out:
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', 'and', 'Python', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', 'not', 'eat', 'cardboard', '.']

# %%
for i in word_tokenize(example_text):
    print(i)
# Out:
# Hello
# Mr.
# Smith
# ,
# how
# are
# you
# doing
# today
# ?
# The
# weather
# is
# great
# and
# Python
# is
# awesome
# .
# The
# sky
# is
# pinkish-blue
# .
# You
# should
# not
# eat
# cardboard
# .

# %%
from nltk.corpus import stopwords

example_sentence = 'This is an example showing off stop word filtration.'
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'ve', 'shan', 'about', 'but', 'now', "doesn't", 'don', 'just', 'myself', "you'll", 'by', 'to', 'an', 'own', 'down', 'they', 'these', "you're", 'being', 'y', 'what', 'only', "hasn't", 'doesn', 'should', 'on', "wasn't", 'no', 'after', 'theirs', 'themselves', 'hers', "that'll", 'ours', 'be', 'doing', "hadn't", 'both', "should've", 'will', 'him', 'over', 'll', 'who', 'shouldn', "weren't", 'from', 'mustn', 'yourself', 'did', 'most', 'itself', 'too', 'for', 'been', 'in', 'o', 'having', 'were', "don't", 'my', "needn't", "she's", 'wasn', 'ourselves', 'yourselves', 'then', 'hadn', 'a', 'of', 'above', 'each', 'further', 'few', 'nor', "isn't", 'himself', 'between', 'didn', 'all', 'under', 'any', 'couldn', 'it', "haven't", 'weren', 'if', 'not', 'such', 'them', 'those', 'during', 'your', 'through', 'had', "aren't", 'his', 'against', 'won', 'out', 'at', 'the', 'ain', 'below', "it's", 'as', "you've", "didn't", 'aren', 'so', 's', 'there', 'this', 'and', 'because', 'is', 'ma', "shan't", 'hasn', 'am', 'haven', 'some', 'off', 'here', 'can', 'we', 'or', 'with', "wouldn't", 'has', 'their', 't', 'i', 'until', 'other', 'very', 're', "couldn't", 'her', 'our', 'whom', "mightn't", 'again', 'herself', 'how', 'mightn', 'where', 'he', 'are', 'do', 'same', 'she', 'you', 'needn', 'isn', 'd', 'does', "you'd", 'which', "shouldn't", 'its', 'than', 'me', 'why', 'yours', 'when', 'm', "won't", 'into', 'once', 'before', 'more', 'was', 'while', 'that', 'have', 'wouldn', 'up', "mustn't"}

# %%
words = word_tokenize(example_sentence)
filtered_sentence = []
for w in words:
    if w not in stop_words:
        filtered_sentence.append(w)
print(filtered_sentence)
# Out:
# ['This', 'example', 'showing', 'stop', 'word', 'filtration', '.']

# %%
filtered_sentence = [w for w in words if not w in stop_words]
print(filtered_sentence)
# Out:
# ['This', 'example', 'showing', 'stop', 'word', 'filtration', '.']

# %% [markdown]
# ### Video 3

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
ps = PorterStemmer()
example_words = ['python', 'pythoner', 'pythoning', 'pythoned', 'pythonly']

for w in example_words:
    print(ps.stem(w))
# Out:
# python
# python
# python
# python
# pythonli

# %%
new_text = 'It is very important to be pythonly while you are pythoning with python. All pythoners have pythoned poorly at least once.'

words = word_tokenize(new_text)
for w in words:
    print(ps.stem(w))
# Out:
# It
# is
# veri
# import
# to
# be
# pythonli
# while
# you
# are
# python
# with
# python
# .
# all
# python
# have
# python
# poorli
# at
# least
# onc
# .

# %% [markdown]
# ### Video 4

# %%
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
train_text = state_union.raw('2005-GWBush.txt')
sample_text = state_union.raw('2006-GWBush.txt')

custom_sent_tokenizer = PunktSentenceTokenizer(train_text)
tokenized = custom_sent_tokenizer.tokenize(sample_text)

# print(train_text)

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)

    except Exception as e:
        print(str(e))

# %%
# process_content()

# %% [markdown]
# ### Video 5

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            chunkGram = r"""Chunk: {<RB.?>*<VB.?>*<NNP>+<NN>?}"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            print(chunked)
            chunked.draw()

    except Exception as e:
        print(str(e))

# %%
# process_content()

# %% [markdown]
# ### Video 6

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            chunkGram = r"""Chunk: {<.*>+}
                                    }<VB.?|IN|DT|TO>+{"""
            chunkParser = nltk.RegexpParser(chunkGram)
            chunked = chunkParser.parse(tagged)
            print(chunked)
            chunked.draw()

    except Exception as e:
        print(str(e))

# %%
# process_content()

# %% [markdown]
# ### Video 7

# %%
def process_content():
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            namedEnt = nltk.ne_chunk(tagged, binary=True)
            namedEnt.draw()
    except Exception as e:
        print(str(e))

# %%
# process_content()

# %% [markdown]
# ### Video 8

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize('cats'))
print(lemmatizer.lemmatize('cacti'))
print(lemmatizer.lemmatize('geese'))
print(lemmatizer.lemmatize('rocks'))
print(lemmatizer.lemmatize('python'))
print(lemmatizer.lemmatize('better', pos='a'))
print(lemmatizer.lemmatize('best', pos='a'))
print(lemmatizer.lemmatize('run'))
print(lemmatizer.lemmatize('run', 'v'))
# Out:
# cat
# cactus
# goose
# rock
# python
# good
# best
# run
# run

# %% [markdown]
# ### Video 9

# %%
print(nltk.__file__)
# Out:
# C:\Users\rodri\anaconda3\lib\site-packages\nltk\__init__.py

# %%
from nltk.corpus import gutenberg
sample = gutenberg.raw('bible-kjv.txt')
tok = sent_tokenize(sample)
print(tok[5:15])
# Out:
# ['1:5 And God called the light Day, and the darkness he called Night.', 'And the evening and the morning were the first day.', '1:6 And God said, Let there be a firmament in the midst of the waters,\nand let it divide the waters from the waters.', '1:7 And God made the firmament, and divided the waters which were\nunder the firmament from the waters which were above the firmament:\nand it was so.', '1:8 And God called the firmament Heaven.', 'And the evening and the\nmorning were the second day.', '1:9 And God said, Let the waters under the heaven be gathered together\nunto one place, and let the dry land appear: and it was so.', '1:10 And God called the dry land Earth; and the gathering together of\nthe waters called he Seas: and God saw that it was good.', '1:11 And God said, Let the earth bring forth grass, the herb yielding\nseed, and the fruit tree yielding fruit after his kind, whose seed is\nin itself, upon the earth: and it was so.', '1:12 And the earth brought forth grass, and herb yielding seed after\nhis kind, and the tree yielding fruit, whose seed was in itself, after\nhis kind: and God saw that it was good.']

# %% [markdown]
# ### Video 10

# %%
from nltk.corpus import wordnet

syns = wordnet.synsets('program')
print(syns[0])
print(syns[0].lemmas()[0].name())
# Out:
# Synset('plan.n.01')
# plan

# %%
print(syns[0].definition())
# Out:
# a series of steps to be carried out or goals to be accomplished

# %%
print(syns[0].examples())
# Out:
# ['they drew up a six-step plan', 'they discussed plans for a new bond issue']

# %%
synonyms = []
antonyms = []

for syn in wordnet.synsets('good'):
    for l in syn.lemmas():
        print('l:',l)
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())
            
print(set(synonyms))
print(set(antonyms))
# Out:
# l: Lemma('good.n.01.good')
# l: Lemma('good.n.02.good')
# l: Lemma('good.n.02.goodness')
# l: Lemma('good.n.03.good')
# l: Lemma('good.n.03.goodness')
# l: Lemma('commodity.n.01.commodity')
# l: Lemma('commodity.n.01.trade_good')
# l: Lemma('commodity.n.01.good')
# l: Lemma('good.a.01.good')
# l: Lemma('full.s.06.full')
# l: Lemma('full.s.06.good')
# l: Lemma('good.a.03.good')
# l: Lemma('estimable.s.02.estimable')
# l: Lemma('estimable.s.02.good')
# l: Lemma('estimable.s.02.honorable')
# l: Lemma('estimable.s.02.respectable')
# l: Lemma('beneficial.s.01.beneficial')
# l: Lemma('beneficial.s.01.good')
# l: Lemma('good.s.06.good')
# l: Lemma('good.s.07.good')
# l: Lemma('good.s.07.just')
# l: Lemma('good.s.07.upright')
# l: Lemma('adept.s.01.adept')
# l: Lemma('adept.s.01.expert')
# l: Lemma('adept.s.01.good')
# l: Lemma('adept.s.01.practiced')
# l: Lemma('adept.s.01.proficient')
# l: Lemma('adept.s.01.skillful')
# l: Lemma('adept.s.01.skilful')
# l: Lemma('good.s.09.good')
# l: Lemma('dear.s.02.dear')
# l: Lemma('dear.s.02.good')
# l: Lemma('dear.s.02.near')
# l: Lemma('dependable.s.04.dependable')
# l: Lemma('dependable.s.04.good')
# l: Lemma('dependable.s.04.safe')
# l: Lemma('dependable.s.04.secure')
# l: Lemma('good.s.12.good')
# l: Lemma('good.s.12.right')
# l: Lemma('good.s.12.ripe')
# l: Lemma('good.s.13.good')
# l: Lemma('good.s.13.well')
# l: Lemma('effective.s.04.effective')
# l: Lemma('effective.s.04.good')
# l: Lemma('effective.s.04.in_effect')
# l: Lemma('effective.s.04.in_force')
# l: Lemma('good.s.15.good')
# l: Lemma('good.s.16.good')
# l: Lemma('good.s.16.serious')
# l: Lemma('good.s.17.good')
# l: Lemma('good.s.17.sound')
# l: Lemma('good.s.18.good')
# l: Lemma('good.s.18.salutary')
# l: Lemma('good.s.19.good')
# l: Lemma('good.s.19.honest')
# l: Lemma('good.s.20.good')
# l: Lemma('good.s.20.undecomposed')
# l: Lemma('good.s.20.unspoiled')
# l: Lemma('good.s.20.unspoilt')
# l: Lemma('good.s.21.good')
# l: Lemma('well.r.01.well')
# l: Lemma('well.r.01.good')
# l: Lemma('thoroughly.r.02.thoroughly')
# l: Lemma('thoroughly.r.02.soundly')
# l: Lemma('thoroughly.r.02.good')
# {'commodity', 'ripe', 'in_effect', 'respectable', 'dependable', 'in_force', 'expert', 'just', 'secure', 'dear', 'serious', 'undecomposed', 'near', 'skillful', 'full', 'estimable', 'unspoilt', 'trade_good', 'effective', 'salutary', 'honorable', 'unspoiled', 'well', 'skilful', 'goodness', 'soundly', 'adept', 'good', 'thoroughly', 'upright', 'sound', 'practiced', 'beneficial', 'honest', 'right', 'proficient', 'safe'}
# {'badness', 'evil', 'bad', 'ill', 'evilness'}

# %%
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('boat.n.01')

print(w1.wup_similarity(w2))
# Out:
# 0.9090909090909091

# %%
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('car.n.01')

print(w1.wup_similarity(w2))
# Out:
# 0.6956521739130435

# %%
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('cat.n.01')

print(w1.wup_similarity(w2))
# Out:
# 0.32

# %% [markdown]
# ### Video 11

# %%
import random
from nltk.corpus import movie_reviews

# %%
documents = [(list(movie_reviews.words(fileid)), category) 
             for category in movie_reviews.categories() 
             for fileid in movie_reviews.fileids(category)]

random.shuffle(documents)

# %%
# print(documents[1])

# %%
all_words = []

for w in movie_reviews.words():
    all_words.append(w.lower())

# %%
all_words = nltk.FreqDist(all_words)

print(all_words.most_common(15))
print(all_words['stupid'])
# Out:
# [(',', 77717), ('the', 76529), ('.', 65876), ('a', 38106), ('and', 35576), ('of', 34123), ('to', 31937), ("'", 30585), ('is', 25195), ('in', 21822), ('s', 18513), ('"', 17612), ('it', 16107), ('that', 15924), ('-', 15595)]
# 253

# %% [markdown]
# ### Video 12

# %%
word_features = list(all_words.keys())[:3000]

def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)
    return features

print(find_features(movie_reviews.words('neg/cv000_29416.txt')))
# Out:
# {'plot': True, ':': True, 'two': True, 'teen': True, 'couples': True, 'go': True, 'to': True, 'a': True, 'church': True, 'party': True, ',': True, 'drink': True, 'and': True, 'then': True, 'drive': True, '.': True, 'they': True, 'get': True, 'into': True, 'an': True, 'accident': True, 'one': True, 'of': True, 'the': True, 'guys': True, 'dies': True, 'but': True, 'his': True, 'girlfriend': True, 'continues': True, 'see': True, 'him': True, 'in': True, 'her': True, 'life': True, 'has': True, 'nightmares': True, 'what': True, "'": True, 's': True, 'deal': True, '?': True, 'watch': True, 'movie': True, '"': True, 'sorta': True, 'find': True, 'out': True, 'critique': True, 'mind': True, '-': True, 'fuck': True, 'for': True, 'generation': True, 'that': True, 'touches': True, 'on': True, 'very': True, 'cool': True, 'idea': True, 'presents': True, 'it': True, 'bad': True, 'package': True, 'which': True, 'is': True, 'makes': True, 'this': True, 'review': True, 'even': True, 'harder': True, 'write': True, 'since': True, 'i': True, 'generally': True, 'applaud': True, 'films': True, 'attempt': True, 'break': True, 'mold': True, 'mess': True, 'with': True, 'your': True, 'head': True, 'such': True, '(': True, 'lost': True, 'highway': True, '&': True, 'memento': True, ')': True, 'there': True, 'are': True, 'good': True, 'ways': True, 'making': True, 'all': True, 'types': True, 'these': True, 'folks': True, 'just': True, 'didn': True, 't': True, 'snag': True, 'correctly': True, 'seem': True, 'have': True, 'taken': True, 'pretty': True, 'neat': True, 'concept': True, 'executed': True, 'terribly': True, 'so': True, 'problems': True, 'well': True, 'its': True, 'main': True, 'problem': True, 'simply': True, 'too': True, 'jumbled': True, 'starts': True, 'off': True, 'normal': True, 'downshifts': True, 'fantasy': True, 'world': True, 'you': True, 'as': True, 'audience': True, 'member': True, 'no': True, 'going': True, 'dreams': True, 'characters': True, 'coming': True, 'back': True, 'from': True, 'dead': True, 'others': True, 'who': True, 'look': True, 'like': True, 'strange': True, 'apparitions': True, 'disappearances': True, 'looooot': True, 'chase': True, 'scenes': True, 'tons': True, 'weird': True, 'things': True, 'happen': True, 'most': True, 'not': True, 'explained': True, 'now': True, 'personally': True, 'don': True, 'trying': True, 'unravel': True, 'film': True, 'every': True, 'when': True, 'does': True, 'give': True, 'me': True, 'same': True, 'clue': True, 'over': True, 'again': True, 'kind': True, 'fed': True, 'up': True, 'after': True, 'while': True, 'biggest': True, 'obviously': True, 'got': True, 'big': True, 'secret': True, 'hide': True, 'seems': True, 'want': True, 'completely': True, 'until': True, 'final': True, 'five': True, 'minutes': True, 'do': True, 'make': True, 'entertaining': True, 'thrilling': True, 'or': True, 'engaging': True, 'meantime': True, 'really': True, 'sad': True, 'part': True, 'arrow': True, 'both': True, 'dig': True, 'flicks': True, 'we': True, 'actually': True, 'figured': True, 'by': True, 'half': True, 'way': True, 'point': True, 'strangeness': True, 'did': True, 'start': True, 'little': True, 'bit': True, 'sense': True, 'still': True, 'more': True, 'guess': True, 'bottom': True, 'line': True, 'movies': True, 'should': True, 'always': True, 'sure': True, 'before': True, 'given': True, 'password': True, 'enter': True, 'understanding': True, 'mean': True, 'showing': True, 'melissa': True, 'sagemiller': True, 'running': True, 'away': True, 'visions': True, 'about': True, '20': True, 'throughout': True, 'plain': True, 'lazy': True, '!': True, 'okay': True, 'people': True, 'chasing': True, 'know': True, 'need': True, 'how': True, 'giving': True, 'us': True, 'different': True, 'offering': True, 'further': True, 'insight': True, 'down': True, 'apparently': True, 'studio': True, 'took': True, 'director': True, 'chopped': True, 'themselves': True, 'shows': True, 'might': True, 've': True, 'been': True, 'decent': True ...

# %%
feature_sets = [(find_features(rev), category) for (rev, category) in documents]
# feature_sets -- Truena si lo imprimes haha

# %% [markdown]
# ### Video 13

# %%
training_set = feature_sets[:1900]
testing_set = feature_sets[1900:]

classifier = nltk.NaiveBayesClassifier.train(training_set)
print("Naive Bayes Algo accuracy percent:", {nltk.classify.accuracy(classifier, testing_set)*100})
classifier.show_most_informative_features(15)
# Out:
# Naive Bayes Algo accuracy percent: {81.0}
# Most Informative Features
#                    sucks = True              neg : pos    =     10.2 : 1.0
#                   annual = True              pos : neg    =      9.7 : 1.0
#                  frances = True              pos : neg    =      9.0 : 1.0
#            unimaginative = True              neg : pos    =      8.3 : 1.0
#                   sexist = True              neg : pos    =      7.0 : 1.0
#                   shoddy = True              neg : pos    =      7.0 : 1.0
#              silverstone = True              neg : pos    =      7.0 : 1.0
#                atrocious = True              neg : pos    =      7.0 : 1.0
#                   regard = True              pos : neg    =      7.0 : 1.0
#                  idiotic = True              neg : pos    =      6.8 : 1.0
#                   turkey = True              neg : pos    =      6.8 : 1.0
#               schumacher = True              neg : pos    =      6.6 : 1.0
#                  cunning = True              pos : neg    =      6.3 : 1.0
#                  kidding = True              neg : pos    =      6.3 : 1.0
#                     mena = True              neg : pos    =      6.3 : 1.0

# %% [markdown]
# ### Video 14

# %%
import pickle

# %%
save_classifier = open('naivebayes.pickle', 'wb')
pickle.dump(classifier, save_classifier)
save_classifier.close()

# %%
classifier_f = open('naivebayes.pickle', 'rb')
classifier = pickle.load(classifier_f)
classifier_f.close()

# %%
print("Naive Bayes Algo accuracy percent:", {nltk.classify.accuracy(classifier, testing_set)*100})
classifier.show_most_informative_features(15)
# Out:
# Naive Bayes Algo accuracy percent: {81.0}
# Most Informative Features
#                    sucks = True              neg : pos    =     10.2 : 1.0
#                   annual = True              pos : neg    =      9.7 : 1.0
#                  frances = True              pos : neg    =      9.0 : 1.0
#            unimaginative = True              neg : pos    =      8.3 : 1.0
#                   sexist = True              neg : pos    =      7.0 : 1.0
#                   shoddy = True              neg : pos    =      7.0 : 1.0
#              silverstone = True              neg : pos    =      7.0 : 1.0
#                atrocious = True              neg : pos    =      7.0 : 1.0
#                   regard = True              pos : neg    =      7.0 : 1.0
#                  idiotic = True              neg : pos    =      6.8 : 1.0
#                   turkey = True              neg : pos    =      6.8 : 1.0
#               schumacher = True              neg : pos    =      6.6 : 1.0
#                  cunning = True              pos : neg    =      6.3 : 1.0
#                  kidding = True              neg : pos    =      6.3 : 1.0
#                     mena = True              neg : pos    =      6.3 : 1.0

# %% [markdown]
# ### Video 15

# %%
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC

# %%
MNB_classifier = SklearnClassifier(MultinomialNB())
MNB_classifier.train(training_set)

print("MNB classifier accuracy percent:", {nltk.classify.accuracy(MNB_classifier, testing_set)*100})
# Out:
# MNB classifier accuracy percent: {82.0}

# %%
#GaussianNB_classifier = SklearnClassifier(GaussianNB())
#GaussianNB_classifier.train(training_set)

#print("GaussianNB classifier accuracy percent:", {nltk.classify.accuracy(GaussianNB_classifier, testing_set)*100})

# %%
BernoulliNB_classifier = SklearnClassifier(BernoulliNB())
BernoulliNB_classifier.train(training_set)

print("BernoulliNB classifier accuracy percent:", {nltk.classify.accuracy(BernoulliNB_classifier, testing_set)*100})
# Out:
# BernoulliNB classifier accuracy percent: {81.0}

# %%
LogisticRegression_classifier = SklearnClassifier(LogisticRegression())
LogisticRegression_classifier.train(training_set)

print("LogisticRegression classifier accuracy percent:", {nltk.classify.accuracy(LogisticRegression_classifier, testing_set)*100})
# Out:
# LogisticRegression classifier accuracy percent: {80.0}
# C:\Users\rodri\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
SGD_classifier = SklearnClassifier(SGDClassifier())
SGD_classifier.train(training_set)

print("SGD classifier accuracy percent:", {nltk.classify.accuracy(SGD_classifier, testing_set)*100})
# Out:
# SGD classifier accuracy percent: {78.0}

# %%
SVC_classifier = SklearnClassifier(SVC())
SVC_classifier.train(training_set)

print("SVC classifier accuracy percent:", {nltk.classify.accuracy(SVC_classifier, testing_set)*100})
# Out:
# SVC classifier accuracy percent: {84.0}

# %%
LinearSVC_classifier = SklearnClassifier(LinearSVC())
LinearSVC_classifier.train(training_set)

print("LinearSVC classifier accuracy percent:", {nltk.classify.accuracy(LinearSVC_classifier, testing_set)*100})
# Out:
# LinearSVC classifier accuracy percent: {78.0}

# %%
NuSVC_classifier = SklearnClassifier(NuSVC())
NuSVC_classifier.train(training_set)

print("NuSVC classifier accuracy percent:", {nltk.classify.accuracy(NuSVC_classifier, testing_set)*100})
# Out:
# NuSVC classifier accuracy percent: {86.0}

# %% [markdown]
# ### Video 16

# %%
from nltk.classify import ClassifierI
from statistics import mode

# %%
class VoteClassifier(ClassifierI):
    def __init__(self, *classifiers):
        self._classifiers = classifiers
        
    def classify(self, features):
        votes = []
        
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        
        return mode(votes)
    
    def confidence(self, features):
        votes = []
        
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
            
        choice_votes = votes.count(mode(votes))
        conf = choice_votes / len(votes)
        
        return conf

# %%
voted_classifier = VoteClassifier(classifier, MNB_classifier, BernoulliNB_classifier, 
                                  LogisticRegression_classifier, SGD_classifier, LinearSVC_classifier, 
                                  NuSVC_classifier)

print("Voted classifier accuracy percent:", {nltk.classify.accuracy(voted_classifier, testing_set)*100})

for i in range(5):
    print("Classification:", {voted_classifier.classify(testing_set[i][0])}, "Confidence %:", {voted_classifier.confidence(testing_set[i][0]) * 100})
# Out:
# Voted classifier accuracy percent: {83.0}
# Classification: {'pos'} Confidence %: {100.0}
# Classification: {'pos'} Confidence %: {100.0}
# Classification: {'pos'} Confidence %: {100.0}
# Classification: {'neg'} Confidence %: {100.0}
# Classification: {'pos'} Confidence %: {71.42857142857143}

# %% [markdown]
# ### Video 17

# %%
# negative
training_set = feature_sets[100:]
testing_set = feature_sets[:100]

classifier = nltk.NaiveBayesClassifier.train(training_set)
print("Naive Bayes Algo accuracy percent:", {nltk.classify.accuracy(classifier, testing_set)*100})
classifier.show_most_informative_features(15)
# Out:
# Naive Bayes Algo accuracy percent: {89.0}
# Most Informative Features
#               schumacher = True              neg : pos    =     12.2 : 1.0
#                   annual = True              pos : neg    =      9.7 : 1.0
#                    sucks = True              neg : pos    =      9.3 : 1.0
#            unimaginative = True              neg : pos    =      8.3 : 1.0
#                  frances = True              pos : neg    =      7.7 : 1.0
#                  idiotic = True              neg : pos    =      7.2 : 1.0
#                   regard = True              pos : neg    =      7.1 : 1.0
#                   shoddy = True              neg : pos    =      6.9 : 1.0
#              silverstone = True              neg : pos    =      6.9 : 1.0
#                   turkey = True              neg : pos    =      6.5 : 1.0
#                  cunning = True              pos : neg    =      6.4 : 1.0
#                 obstacle = True              pos : neg    =      6.4 : 1.0
#                  singers = True              pos : neg    =      6.4 : 1.0
#                  jumbled = True              neg : pos    =      6.3 : 1.0
#                     mena = True              neg : pos    =      6.3 : 1.0

# %%
MNB_classifier.train(training_set)
print("MNB classifier accuracy percent:", {nltk.classify.accuracy(MNB_classifier, testing_set)*100})

BernoulliNB_classifier.train(training_set)
print("BernoulliNB classifier accuracy percent:", {nltk.classify.accuracy(BernoulliNB_classifier, testing_set)*100})

LogisticRegression_classifier.train(training_set)
print("LogisticRegression classifier accuracy percent:", {nltk.classify.accuracy(LogisticRegression_classifier, testing_set)*100})

SGD_classifier.train(training_set)
print("SGD classifier accuracy percent:", {nltk.classify.accuracy(SGD_classifier, testing_set)*100})

SVC_classifier.train(training_set)
print("SVC classifier accuracy percent:", {nltk.classify.accuracy(SVC_classifier, testing_set)*100})

LinearSVC_classifier.train(training_set)
print("LinearSVC classifier accuracy percent:", {nltk.classify.accuracy(LinearSVC_classifier, testing_set)*100})

NuSVC_classifier.train(training_set)
print("NuSVC classifier accuracy percent:", {nltk.classify.accuracy(NuSVC_classifier, testing_set)*100})
# Out:
# MNB classifier accuracy percent: {87.0}
# BernoulliNB classifier accuracy percent: {89.0}
# LogisticRegression classifier accuracy percent: {84.0}
# SGD classifier accuracy percent: {83.0}
# SVC classifier accuracy percent: {90.0}
# LinearSVC classifier accuracy percent: {85.0}
# NuSVC classifier accuracy percent: {90.0}

# %% [markdown]
# ### Video 18

# %%
import nltk
import random
#from nltk.corpus import movie_reviews
from nltk.classify.scikitlearn import SklearnClassifier
import pickle
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from nltk.classify import ClassifierI
from statistics import mode
from nltk.tokenize import word_tokenize



class VoteClassifier(ClassifierI):
    def __init__(self, *classifiers):
        self._classifiers = classifiers

    def classify(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        return mode(votes)

    def confidence(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)

        choice_votes = votes.count(mode(votes))
        conf = choice_votes / len(votes)
        return conf
    
short_pos = open("positive.txt","r").read()
short_neg = open("negative.txt","r").read()

# move this up here
all_words = []
documents = []


#  j is adject, r is adverb, and v is verb
#allowed_word_types = ["J","R","V"]
allowed_word_types = ["J"]

for p in short_pos.split('\n'):
    documents.append( (p, "pos") )
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())

    
for p in short_neg.split('\n'):
    documents.append( (p, "neg") )
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())



save_documents = open("documents.pickle","wb")
pickle.dump(documents, save_documents)
save_documents.close()


all_words = nltk.FreqDist(all_words)


word_features = list(all_words.keys())[:5000]


save_word_features = open("word_features5k.pickle","wb")
pickle.dump(word_features, save_word_features)
save_word_features.close()


def find_features(document):
    words = word_tokenize(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features

featuresets = [(find_features(rev), category) for (rev, category) in documents]

random.shuffle(featuresets)

save_features = open("featuresets.pickle","wb")
pickle.dump(featuresets, save_features)
save_features.close()

print(len(featuresets))

testing_set = featuresets[10000:]
training_set = featuresets[:10000]


classifier = nltk.NaiveBayesClassifier.train(training_set)
print("Original Naive Bayes Algo accuracy percent:", (nltk.classify.accuracy(classifier, testing_set))*100)
classifier.show_most_informative_features(15)

###############
save_classifier = open("pickled_algos/originalnaivebayes5k.pickle","wb")
pickle.dump(classifier, save_classifier)
save_classifier.close()

MNB_classifier = SklearnClassifier(MultinomialNB())
MNB_classifier.train(training_set)
print("MNB_classifier accuracy percent:", (nltk.classify.accuracy(MNB_classifier, testing_set))*100)

save_classifier = open("pickled_algos/MNB_classifier5k.pickle","wb")
pickle.dump(MNB_classifier, save_classifier)
save_classifier.close()

BernoulliNB_classifier = SklearnClassifier(BernoulliNB())
BernoulliNB_classifier.train(training_set)
print("BernoulliNB_classifier accuracy percent:", (nltk.classify.accuracy(BernoulliNB_classifier, testing_set))*100)

save_classifier = open("pickled_algos/BernoulliNB_classifier5k.pickle","wb")
pickle.dump(BernoulliNB_classifier, save_classifier)
save_classifier.close()

LogisticRegression_classifier = SklearnClassifier(LogisticRegression())
LogisticRegression_classifier.train(training_set)
print("LogisticRegression_classifier accuracy percent:", (nltk.classify.accuracy(LogisticRegression_classifier, testing_set))*100)

save_classifier = open("pickled_algos/LogisticRegression_classifier5k.pickle","wb")
pickle.dump(LogisticRegression_classifier, save_classifier)
save_classifier.close()


LinearSVC_classifier = SklearnClassifier(LinearSVC())
LinearSVC_classifier.train(training_set)
print("LinearSVC_classifier accuracy percent:", (nltk.classify.accuracy(LinearSVC_classifier, testing_set))*100)

save_classifier = open("pickled_algos/LinearSVC_classifier5k.pickle","wb")
pickle.dump(LinearSVC_classifier, save_classifier)
save_classifier.close()


##NuSVC_classifier = SklearnClassifier(NuSVC())
##NuSVC_classifier.train(training_set)
##print("NuSVC_classifier accuracy percent:", (nltk.classify.accuracy(NuSVC_classifier, testing_set))*100)


SGDC_classifier = SklearnClassifier(SGDClassifier())
SGDC_classifier.train(training_set)
print("SGDClassifier accuracy percent:",nltk.classify.accuracy(SGDC_classifier, testing_set)*100)

save_classifier = open("pickled_algos/SGDC_classifier5k.pickle","wb")
pickle.dump(SGDC_classifier, save_classifier)
save_classifier.close()
# Out:
# 10664
# Original Naive Bayes Algo accuracy percent: 71.6867469879518
# Most Informative Features
#               engrossing = True              pos : neg    =     21.1 : 1.0
#                  generic = True              neg : pos    =     15.6 : 1.0
#                 mediocre = True              neg : pos    =     15.6 : 1.0
#                inventive = True              pos : neg    =     15.1 : 1.0
#                  routine = True              neg : pos    =     14.9 : 1.0
#                   boring = True              neg : pos    =     13.8 : 1.0
#                     flat = True              neg : pos    =     13.7 : 1.0
#                 intimate = True              pos : neg    =     13.1 : 1.0
#               refreshing = True              pos : neg    =     13.1 : 1.0
#                    vivid = True              pos : neg    =     12.4 : 1.0
#                     warm = True              pos : neg    =     12.3 : 1.0
#                wonderful = True              pos : neg    =     11.9 : 1.0
#                realistic = True              pos : neg    =     11.7 : 1.0
#                 mindless = True              neg : pos    =     11.6 : 1.0
#              mesmerizing = True              pos : neg    =     11.1 : 1.0
# MNB_classifier accuracy percent: 72.59036144578313
# BernoulliNB_classifier accuracy percent: 72.89156626506023
# LogisticRegression_classifier accuracy percent: 73.64457831325302
# LinearSVC_classifier accuracy percent: 71.23493975903614
# SGDClassifier accuracy percent: 72.13855421686746

# %% [markdown]
# ### Video 19

# %%
import sentiment_mod as s

print(s.sentiment("This movie was awesome! The acting was great, plot was wonderful, and there were pythons...so yea!"))
print(s.sentiment("This movie was utter junk. There were absolutely 0 pythons. I don't see what the point was at all. Horrible movie, 0/10"))
# Out:
# ('pos', 1.0)
# ('neg', 1.0)

# %% [markdown]
# ### Video 20

# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import time
import json

from config import ckey, csecret, atoken, asecret

search_words = ['twitch']

class listener(StreamListener):

    def on_data(self, data):
        try:
            all_data = json.loads(data)
        except:
            return True

        tweet = all_data["text"]
        print(sentiment(tweet))
        sentiment_value, confidence = s.sentiment(tweet)
        print(tweet, sentiment_value, confidence)
        
        if confidence >= 0.8:
            with open('twitter-out.txt', 'a') as output:
                output.write(sentiment_value)
                output.write('\n')      

        return True

    def on_error(self, status):
        print(status)

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

twitterStream = Stream(auth, listener())
twitterStream.filter(track=search_words)
# Out:
# ('pos', 0.5714285714285714)
# RT @konataform: the listening party is in 90 minutes! (well, 78 minutes as of this tweet) https://t.co/WrIBRRSaWY https://t.co/KHC9vpHwQ7 pos 0.6
# ('neg', 0.7142857142857143)
# Live right now with some warzone dubs!! Stop by &amp; don’t forget to follow/sub- https://t.co/Z7PBBpvSa6… https://t.co/7fpeZCrnQ9 neg 0.8
# ('neg', 0.8571428571428571)
# RT @TutosBS: Y twitch aun no me aprueba los emotes
#
# https://t.co/Mcnq35vCnq neg 0.8
# ('neg', 1.0)
# RT @Vinniehacker: streaming rn!! https://t.co/iulVGwSuK0 neg 1.0
# ('neg', 0.8571428571428571)
# I’m live on Twitch - Watch me at https://t.co/DBj3EAXgJt neg 1.0
# ('neg', 1.0)
# DBD NOSSO DE CADA RAGE NOS DAI HOJE [LGBTQIA+] https://t.co/XR2llnmFUA neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# minecraft !!
#
# @336gaming
# https://t.co/63YGnTGj8e neg 1.0
# ('neg', 1.0)
# RT @D3athNinja: We LIVE
# Hacking The World on Watch Dogs: Legion
# https://t.co/J4zfI6Ve5l
# @AvianGameCo neg 1.0
# ('neg', 1.0)
# RT @TheStrangeRebel: We're playing The Last of Us II today! Let's see what Ellie survives next shall we?
# Join live now: https://t.co/ZBCcl… neg 1.0
# ('neg', 1.0)
# Trying to Avoid More Carnage | Omega Ruby Randomzer Nuzlocke
#
# Live Now At: https://t.co/kAGkqRA31i
#
# #Pokemon #ORAS #Nuzlocke #ChallengeRun neg 1.0
# ('neg', 0.8571428571428571)
# Going live at 5:15 PM PST/ 8:15 PM PST!!!
#
# BEST MUSTACHE AND LOCK will be on 2k!!
#
# https://t.co/aDEt5upTLy neg 0.8
# ('neg', 0.5714285714285714)
# Ela é fodaaa ou não é, recomendo todos a conhecerem o trabalho dela!!!! pos 0.6
# ('neg', 1.0)
# Diet League - 2v2 All the hours, half the skill. DAY 5 https://t.co/xz2vSgFIV6 neg 1.0
# ('pos', 0.7142857142857143)
# RT @liljarviss: Gonna play Fortnite live on Twitch in 30 minutes!! Gotta be more careful this time.
#
# Sharing link in 30 minutes #FreeJarvis pos 1.0
# ('pos', 0.8571428571428571)
# Who do we got winning? @ElevateGG or @ez5gg?
#
# Make sure to tune in &amp; cheer on your favorite team! 😉
#
# 📺… https://t.co/UAHdKaWwOv pos 1.0
# ('neg', 0.5714285714285714)
# RT @Akilaverse: I'm officially a @twitch Affiliate!!! I feel like a dance party is the best way to celebrate...with tunes by ME as I'll be… neg 0.6
# ('neg', 0.8571428571428571)
# RT @laurelrothamel: We are live rn!
#
# Gonna do a little DNA test on my new pupper, then playing “When The Past Was Around” for some chill ha… neg 0.8
# ('neg', 0.5714285714285714)
# RT @VampireArcadia: February 15th at 9PM EST:  No RSVP required.
#
# https://t.co/vdMKC4N1Vx
#
# @ISW_TheSeeker vs. @LNycholas2000 FT10
#
# @feebe… pos 0.6
# ('pos', 0.7142857142857143)
# RT @RedKath: Na moral? Tá lançado o desafio pra vocês! Esse homem EU NUNDA VI BEBER, imagina uma live alcoólica na moral...
# Eu DUVIDO vocês… pos 1.0
# ('neg', 1.0)
# Doing a hangout livestream and just playing some Stardew Valley.  If anyone drops by lets talk about #TTRPG and… https://t.co/eahqI1BlWE neg 1.0
# ('neg', 1.0)
# Après ce 1st try dans #SkulTheHeroSlayer je vais pouvoir crâner 😅
#
# #TwitchClips #TwitchMoments #TwitchFR #streamer… https://t.co/xVwbin5Y5g neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('pos', 0.7142857142857143)
# To clarify, this is a week-long event in which LRock is going for one-credit clears in a number of challenging arca… https://t.co/AkNXJnKII5 pos 1.0
# ('neg', 1.0)
# A Scatter-brain's Scatter-stream! Sending Positive Vibes!!
#
# NiroSeza is LIVE!!
#
# https://t.co/fYv5LKYKr6 https://t.co/RaAAmRXBhG neg 1.0
# ('pos', 0.8571428571428571)
# RT @Mind1Official: Let’s blow up some spaceships! @eveonline
#
# https://t.co/5XXehxc9UY
#
# Stream powered by @lumiastream
#
# #twitch #streamer #n… pos 1.0
# ('neg', 0.8571428571428571)
# RT @pluroco: Support a black stream this month neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('neg', 1.0)
# Come chat!
# https://t.co/B7IFjf5XNI neg 1.0
# ('neg', 0.8571428571428571)
# RT @EbonixSims: It’s me 🥺
#
# UK’s First Black Female Twitch Ambassador 😭✨🎉
#
# It means so much, that in even less than a year after being part… neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('neg', 1.0)
# Check out CURRENT ZEN STAGE!!!! sub goal-(23-30)-!sub !prime https://t.co/Gk5QhnajM7 forget to tweet out my live smh come thru neg 1.0
# ('neg', 0.7142857142857143)
# Going live in 15. New sub badge is lit. Come  hang out at
# https://t.co/o5K8ytie4Y neg 0.6
# ('neg', 1.0)
# Live now! w/@Vulixeee @tri_bune @PistoIPIay @o_Dimensionz
#
# https://t.co/xCgV9uld7I neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('neg', 1.0)
# FIGHT CLUB https://t.co/sHVcmxjNmZ neg 1.0
# ('neg', 1.0)
# RT @Parruna: There was a time when Twitch was all about gaming... neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('neg', 0.8571428571428571)
# I forgot to stream cause hw live at https://t.co/WoVHdxkn7N neg 0.8
# ('neg', 1.0)
# rangers for LIFE | Wasteland 3 https://t.co/fLjsmws3wy neg 1.0
# ('neg', 0.7142857142857143)
# RT @deathbybananas3: Live right now with some warzone dubs!! Stop by &amp; don’t forget to follow/sub- https://t.co/Z7PBBpvSa6
#
# @PromoteAMGamer… neg 0.8
# ('neg', 0.7142857142857143)
# Where it all began, sort of. Never played this. Not even the original. EXCITED.
#
# You catch it here:… https://t.co/xVbIdbI838 neg 0.8
# ('neg', 1.0)
# https://t.co/sdabCUrEr4
#
# 2/2
#
# So if you want Pokemon packs, hit me up in DMs or my pokemon trainer in crime @MariYume_ 😎 neg 1.0
# ('neg', 0.8571428571428571)
# RT @EbonixSims: It’s me 🥺
#
# UK’s First Black Female Twitch Ambassador 😭✨🎉
#
# It means so much, that in even less than a year after being part… neg 1.0
# ('neg', 0.8571428571428571)
# el twitch streamer when neg 0.8
# ('neg', 0.8571428571428571)
# Going live soon🥰 Long streams all week👀 https://t.co/lMzB8OYZvK neg 0.8
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('neg', 1.0)
# RT @Soberanogg: #GoLions https://t.co/buN0TT3l7L neg 1.0
# ('neg', 0.7142857142857143)
# https://t.co/6EayKcrjjM stream de 18 horas jugando fnaf neg 0.6
# ('neg', 1.0)
# GG ibai neg 1.0
# ('neg', 1.0)
# RT @oheymaria: we grindin' yessiiirrr https://t.co/wN5rBol3Sp neg 1.0
# ('pos', 0.8571428571428571)
# Hey there my beautiful peeps stream is LIVE!! Now... Hope to see your beautiful faces there..
#  https://t.co/He3kpjan88 pos 1.0
# ('neg', 1.0)
# RT @SpiraNovaTV: HI IM LIVE PLAYING VAL AGAIN HA PLS SUPPORT ME https://t.co/sno5a6pnx1 neg 1.0
# ('neg', 1.0)
# RT @WZHappening: Another one baby. Still absolutely FREE. Still 100% LIVE
#
# Virtual Pit sign up: https://t.co/TZyY4fgz7p
#
# Subscribe for excl… neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 1.0)
# RT @STRAWBUNNlES: finishing up a commission, then playing more FFX!!
#
# https://t.co/P8lQbR6NcM https://t.co/7g0wZaxasy neg 1.0
# ('neg', 0.5714285714285714)
# https://t.co/ZmqdgD2Y7L GRACIAS A TODOS LOS QUE HABÉIS ESTADO HOY, HA SIDO GENIAL, 6h de directo, os quiero un besito pos 0.6
# ('neg', 0.5714285714285714)
# RT @Sir_Hasp: 120-Star Marathon! Nostalgia trip, playing SM64 for the first time in forever. #Twitch #Mario #SuperMario64 #Marathon
# https:/… neg 0.6
# ('neg', 1.0)
# DRAGON AGE TIME WITH HHYUSE https://t.co/XNpbtaBQ3G neg 1.0
# ('pos', 0.8571428571428571)
# RT @Twitch: Our newest Twitch Ambassador's about good vibes, big time creativity and a deep love of Simlish.
#
# Give a ebonixYERRR to @Eboni… pos 1.0
# ('neg', 1.0)
# Check out my broadcast from my PlayStation 4! #PS4live (Call of Duty®: Black Ops Cold War)  live at https://t.co/Qg7cQKxnMj neg 1.0
# ('neg', 1.0)
# RT @Tankk___: Carry Season !sub !socials https://t.co/38TZ0dAJbe neg 1.0
# ('neg', 1.0)
# Starting now! neg 1.0
# ('neg', 1.0)
# RT @SpiraNovaTV: HI IM LIVE PLAYING VAL AGAIN HA PLS SUPPORT ME https://t.co/sno5a6pnx1 neg 1.0
# ('pos', 0.8571428571428571)
# {Esp-Eng} {CHL} compartimos y nos vamos al DBD !Jugar !redes !pack Team: Coquet@s https://t.co/a4jlktiXtn pos 1.0
# ('neg', 0.7142857142857143)
# RT @TRGVash: Gameplay mais criminosa possível jogador de qualidade duvidosa https://t.co/IIfyZPBbmx neg 0.6
# ('pos', 0.5714285714285714)
# Echadle un vistazo al canal de @SirBarbas. No solo porque es una de mis personas favoritas sino porque tiene montad… https://t.co/pTabGVC5tW pos 0.8
# ('neg', 1.0)
# Pick my Guns? https://t.co/DL9OJx1Eyr neg 1.0
# ('pos', 0.7142857142857143)
# RT @liljarviss: Gonna play Fortnite live on Twitch in 30 minutes!! Gotta be more careful this time.
#
# Sharing link in 30 minutes #FreeJarvis pos 1.0
# ('neg', 1.0)
# RT @CruxifyDaGod: 400$ POT TOURNEY !SUB sub goal 36/40 https://t.co/QxlTv2cfTY neg 1.0
# ('neg', 1.0)
# RT @StayLOVEleigh: @emzberri @ToxplicityAU https://t.co/sbH30fF2WS neg 1.0
# ('neg', 1.0)
# Estou ao vivo na Twitch desenhando :0 https://t.co/niQJdS7dCK neg 1.0
# ('neg', 1.0)
# SOY GLOGLO CAVARA neg 1.0
# ('neg', 1.0)
# Check out my broadcast from my PlayStation 4! #PS4live (TEKKEN™7)  live at https://t.co/NusbVxzHE1 neg 1.0
# ('neg', 0.5714285714285714)
# We're hosting therealchubbs52 playing #FarmingSimulator19 with 29 viewers on Twitch! Be sure to show them some supp… https://t.co/4i6N1gtfgG neg 0.6
# ('neg', 1.0)
# Gladiator Short Stream 2s/3s/RBGs !vibes !discord  https://t.co/BbPQ5oJX2y neg 1.0
# ('neg', 1.0)
# RT @_uchiwalex: [FR/PC] Ranked Champion  https://t.co/OdQ3hYdEvA neg 1.0
# ('neg', 1.0)
# RT @PatrickAdemo: Pour ceux qui s'font chier
#
# https://t.co/k6kYrqiv4R neg 1.0
# ('neg', 1.0)
# Eating and taking a quick break, be live in a little bit to grind more apex neg 1.0
# ('neg', 1.0)
# Check out my broadcast from my PlayStation 4! #PS4live (Call of Duty®: Black Ops Cold War)  live at https://t.co/8BPItYoHjT neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# Check out my broadcast from my PlayStation 4! #PS4live (Call of Duty®: Modern Warfare®)  live at https://t.co/ck91bZUlPY neg 1.0
# ('pos', 0.7142857142857143)
# RT @WillItHomestuck: We're live on Twitch with our Community Read!! Come watch our Discord server read your fic :33 (link below) https://t.… pos 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('neg', 1.0)
# RT @maximilian_: STREAMING ON TWITCH! KILLER INSTINCT Twitch Rivals Tournament #BringBackKi (2-1) @KillerInstinct @Xbox @TwitchRivals @Xbox… neg 1.0
# ('neg', 1.0)
# @emzberri https://t.co/dtj0YxHg87 for weird variety times! we just like to vibe neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# STARTING THE LAST CLASS TRIAL?! IS MONOKUMA LYING? COME FIND OUT NOW! neg 1.0
# ('neg', 1.0)
# 🇪🇸 DISEÑANDO ABURRIDO 🇪🇸 https://t.co/mCC6UEzqZU neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# More Halo: CE with @AndyTheBlanch. https://t.co/gz2aLSkuMM https://t.co/oMjjokuKA0 neg 1.0
# ('neg', 0.8571428571428571)
# I'm not sure what are you doing, but if you like #KillerInstinct you should be watching this:
#
# Max Presents: KILLER… https://t.co/3MeseDgtYW neg 1.0
# ('neg', 1.0)
# Battlefront 2 &amp; Chill [New Player] https://t.co/CGJPJvd5wd neg 1.0
# ('pos', 0.5714285714285714)
# mano essa live tá muito boa
# me fazendo refletir real pos 0.6
# ('neg', 0.7142857142857143)
# RT @platholyte: okay we're gonna be live at 7pm CST tonight, streaming some ARAM games in League of Legends! https://t.co/OxGK8oywRE https:… neg 0.8
# ('neg', 1.0)
# Time for more Map exploration! Let's see where the game takes us. Join us for Ramble Through the Mojave ep. 8!
# https://t.co/0Rk4cKNDqc neg 1.0
# ('neg', 1.0)
# BAJAN LOBBY TONIGHT @ 9 !!
#
# @OneCallBellies @IAmRamonG @_PastorBishop_ neg 1.0
# ('neg', 1.0)
# The AllFather Odin !!     !comandos https://t.co/odgRWQJcOE neg 1.0
# ('neg', 1.0)
# RT @Gui1erme: COMO DISSE
# 18 MINUTOS E 23 SEGUNDOS DPS
# ESTOU ON COM A LIVE MAIS GOOD VIBES DESSA SEGUNDONA
# VEM
#
# https://t.co/XQmv0Olilw neg 1.0
# ('neg', 1.0)
# Check out my broadcast from my PlayStation 4! #PS4live (HITMAN 3)  live at https://t.co/A81tG6owoE neg 1.0
# ('neg', 1.0)
# DBD time to scream like a little girl T-T https://t.co/IXlPg1lOpF neg 1.0
# ('neg', 0.8571428571428571)
# @HoustonRockets @TISSOT Rockets Watch Party about to go live at 7 🚀https://t.co/cwLyVpX6Pj! neg 0.8
# ('neg', 1.0)
# RT @MomentumSonic: Finally the amazon, twitch, metroid, sonic crossover we've been waiting for neg 1.0
# ('neg', 1.0)
# @PromotingStream Cod, overwatch, sea of thieves https://t.co/cUE3yRPTIn neg 1.0
# ('pos', 0.8571428571428571)
# I'm gonna be streaming for the first time playing melee!!! Hopefully everything goes along well :)
# https://t.co/t0qTpYCHY6 pos 1.0
# ('neg', 1.0)
# https://t.co/PucI3gGjXn ME METÍ AL TRADING 😳
# YA ESTAMOS EN DIRECTOOOOOOOOOOO
#
# ❤️Y🔀¿ME AYUDAN COMPARTIENDO?🥺 https://t.co/AUH73PlJc3 neg 1.0
# ('neg', 1.0)
# If you guys don’t have plans come hangout on twitch we are reviewing metal albums and helping to raise money for Ki… https://t.co/4kv4ciu6r7 neg 1.0
# ('pos', 0.8571428571428571)
# RT @Twitch: Our newest Twitch Ambassador's about good vibes, big time creativity and a deep love of Simlish.
#
# Give a ebonixYERRR to @Eboni… pos 1.0
# ('neg', 1.0)
# RT @BunnyAyu: AAA IM LIVE ft. cape
# I MISSED YOU come hang
# https://t.co/VEMYrd0gqS https://t.co/Q1BS6LYdfq neg 1.0
# ('neg', 1.0)
# RT @simply_BOS: LIVE! Sandlot league game vs @ohhte at 8pm est https://t.co/abFth7XD4C neg 1.0
# ('neg', 0.8571428571428571)
# Ooops! End of season rush! https://t.co/EhZVsO6v8u neg 1.0
# ('pos', 0.8571428571428571)
# Hey! If anyone looking for a twitch overlay package HMU asap I'm making them at the best prices.
# #twitch #overlay… https://t.co/mZDIoam48S pos 1.0
# ('neg', 1.0)
# 早朝　apex  https://t.co/9qTMBppXpO neg 1.0
# ('neg', 1.0)
# RT @C9Mang0: https://t.co/iT6ZHW0Wci
#
# jerking before valorant grind
#
# SMASHERS GAMBIT GRIND ? neg 1.0
# ('neg', 1.0)
# RECEIVED MY ELGATO TODAY! FACE REVEAL TOMORROW! CHECK OUT MY PANELS! https://t.co/ISF4Qzzq8v neg 1.0
# ('pos', 0.7142857142857143)
# RT @shiniggx: Boa noite pessoal, depois de muita luta consegui resolver os problemas aqui e estamos ao vivo novamente em, cola que nem eu s… pos 1.0
# ('neg', 0.8571428571428571)
# Just went live! Come and join the stream :) https://t.co/FIaocNqn56
# #playstation4 #Twitch #youtube #games neg 0.8
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# YA ESTAMOS CON LA @NoTiltGG WORLDS!!
#
# EMPEZAMOS CON:
# CHILE vs URUGUAY
#
# Y SEGUIMOS CON MEXICO vs COSTA RICA!!
#
# DIA DE LO… neg 1.0
# ('neg', 1.0)
# RT @KreeksFUT: EN LIVE !
#
# DEBUT DE LIVE + ANNONCE RP !
#
# https://t.co/jS7MApAhoo neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# If this doesn't make you want to follow me on Twitch, then I don't know what will. #Vtuber #VTuberEN #ENVtuber
#
# https://t.co/PIHDOz61X6 neg 1.0
# ('neg', 1.0)
# #lurxquad member Drayle88 now streaming! Now playing Minecraft! https://t.co/fODVdzKC0b neg 1.0
# ('neg', 1.0)
# just vibing playing a bit.  https://t.co/gL9DmgsKV0 neg 1.0
# ('neg', 1.0)
# RT @ar_jorge1987: De #velez al mundial, vamos a darle al FIFA 21! Me cruzare a Mauro Zarate?
# https://t.co/eGaziWo0YG neg 1.0
# ('neg', 0.5714285714285714)
# RT @guimarcondes4: Tô com meu duo, procurando mais 1 pro trio eu sou Igl, patchmacker e meu duo é fragger, eu tenho 550$ na minha conta twi… pos 0.6
# ('neg', 1.0)
# Live on twitch playing warzone https://t.co/5QatOQbnbk neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 1.0)
# LIVE ON TWITCH 🚨
#
# Happy Minecraft Monday!
#
# https://t.co/NtWA1rSxZJ
#
# https://t.co/NtWA1rSxZJ
#
# https://t.co/NtWA1rSxZJ neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('pos', 0.8571428571428571)
# RT @GREEEDLA: Winners finals starting very soon  !! https://t.co/2l5V5xCF3N pos 1.0
# ('neg', 1.0)
# Ya estamos en vivo!!
#
# Facebook: https://t.co/6k4HlnbBXg
# Twitch: https://t.co/yZ4kvl82fH
# YouTube: https://t.co/jMN1uByo5B neg 1.0
# ('neg', 1.0)
# #lurxquad member xxTombstonexx now streaming! Now playing Monster Hunter: World! https://t.co/os7jKWpHLY neg 1.0
# ('neg', 1.0)
# Time for some dead by daylight to get my mind off how bad the Bruins are playing.  https://t.co/hpTgPPoouN neg 1.0
# ('neg', 1.0)
# DEPOIS DE MUITO TEMPO, voltei kkkkkkk https://t.co/7MYHf6EeIF neg 1.0
# ('neg', 1.0)
# RT @Kicciana2K: CURRENT ZEN STAGE 🖤
#
# https://t.co/gPWtGqGeWz neg 1.0
# ('neg', 1.0)
# this mf really tryna fool us again. neg 1.0
# ('neg', 1.0)
# RT @FearFragr: Live now! w/@Vulixeee @tri_bune @PistoIPIay @o_Dimensionz
#
# https://t.co/xCgV9uld7I neg 1.0
# ('neg', 1.0)
# 🔴LIVE NOW 🔴
# Maybe finishing Fable tonight?  Or getting reallyyyyyy close.
#
# https://t.co/rOTluCUkoH neg 1.0
# ('neg', 0.5714285714285714)
# Okies well going to stream VRC little late then planned but yeah, will be not using VR since I returned the VR stuf… https://t.co/fY6puDc4xm neg 0.6
# ('neg', 1.0)
# MENOS DE 24 HORAS PARA LA HORA 0 neg 1.0
# ('neg', 0.8571428571428571)
# im doing a birthday steam at https://t.co/SQjXKR8GN7 by and say hi neg 0.8
# ('neg', 1.0)
# RT @Conviicts: Well im feeling pretty goood gonna try and stream tonight. https://t.co/NrWNOdeLEe neg 1.0
# ('neg', 0.8571428571428571)
# Just went live! https://t.co/6bkhaemtvf neg 0.8
# ('neg', 1.0)
# @DNPthree I have subscribed to both grid gaming and dnp3 on twitch and I still can’t get the 3500 chances neg 1.0
# ('neg', 0.5714285714285714)
# @twitchpr0mo Hola!... en unas horas hare stream... si me pueden ayudar viendome se los agradeceria bastante
# https://t.co/3kRu1opJuT pos 0.6
# ('neg', 0.8571428571428571)
# I'm live on twitch, Playing Black Desert Online https://t.co/K7SSKs8pOt neg 0.8
# ('pos', 0.7142857142857143)
# RT @MarombeiroT: Quer saber mais sobre o cenário competitivo de e-sports?
# Ta rolando uma gravação do podcast da @blackhatgg sobre isso!!!
# P… pos 1.0
# ('pos', 0.7142857142857143)
# @Alonso_men12 Te juro, creo que son las predeterminadas de twitch xd pos 1.0
# ('neg', 0.5714285714285714)
# Amanhã a nossa querida Clementine esta de volta, com o primeiro episódio da temporada 3 de The Walking Dead. Espero… https://t.co/jiZ3f7686u pos 0.6
# ('pos', 0.8571428571428571)
# @DracTactics joins young Chris Redfield(before being a bodybuilder) on the DS version of the events that happen dur… https://t.co/TyWJ18dh15 pos 1.0
# ('neg', 1.0)
# https://t.co/KLc6GbESel https://t.co/n1i1i7oy0Z neg 1.0
# ('neg', 1.0)
# Little COD tonight! Let's shoot the shit... I mean.. shoot the ship....or both. #COD #callofduty #twitch #streamer… https://t.co/6CkmX6m6xh neg 1.0
# ('pos', 0.5714285714285714)
# Live Now!
#
# Have some new stuffs and ready to play some games with you all! Come hang out and lets have some fun!
#
# https://t.co/SmfyiTMEOb pos 0.6
# ('neg', 1.0)
# RT @DavidAlvareeezy: lovey dovey stream! https://t.co/8qDrdDES4x neg 1.0
# ('neg', 1.0)
# RT @ioniakuroda: I won’t be doing Touhou 7 again tonight. It’ll be replaced with Dark Souls, the switch remaster one. Same time! Hope to se… neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('neg', 0.8571428571428571)
# Join me and my friends #live now for some #hightimes playing some #Minecraft over at https://t.co/kHfGXbr5cb. Come… https://t.co/GSea1pg5p5 neg 0.8
# ('neg', 0.7142857142857143)
# new graphics card get in here! https://t.co/SUZDB07mq2 neg 0.8
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('pos', 0.8571428571428571)
# Going live on Twitch, come join me and the chat for another day of epic gameplay! https://t.co/rE4JEvVVky pos 1.0
# ('neg', 1.0)
# RT @Kate_Baker: Omg! Is that ANOTHER https://t.co/LTctNa5X9b schedule for the week? What is happening? Please stop by if you have a chance!… neg 1.0
# ('neg', 1.0)
# Going live tonight at 8PM EST
# Taking a break from pokemon, this time we are playing One night in the Woods! Feel fr… https://t.co/4Yc0Ktmv1b neg 1.0
# ('neg', 0.5714285714285714)
# RT @cachoo01: Tocaron TOTY asi que ya sabeis!!! pos 0.6
# ('neg', 1.0)
# can anyone join my stream https://t.co/41c5z5KL4v neg 1.0
# ('neg', 0.8571428571428571)
# yerrrrrr team sole on rebirth island https://t.co/zxSrEvINB3 neg 0.8
# ('neg', 0.8571428571428571)
# I’m live on Twitch - Watch me at https://t.co/oKXchrxJuL neg 1.0
# ('neg', 1.0)
# RT @dannyryan: 24/7 stream of eth2 client logs by @ethStaker
# (flips between 5 clients!)
#
# https://t.co/0cK98tCzfB
#
# Aside from just generall… neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 0.8571428571428571)
# We're doing it live!
# https://t.co/9kY7tajlA8 neg 0.8
# ('neg', 1.0)
# RT @itskiiree: Check out my broadcast from my PlayStation 4! #PS4live (Fortnite)  live at https://t.co/AsbgJpJeKo neg 1.0
# ('neg', 0.8571428571428571)
# Going #live at 8 pm EST on #Twitch! Come, hang out as we @PlayDauntless and grind out the high-level escalations!
# https://t.co/JSrh4JUp7t neg 0.8
# ('neg', 1.0)
# subpar comp duos https://t.co/dRFwISA9y4 neg 1.0
# ('neg', 0.5714285714285714)
# [MEX] Traje de Pikachu a los 500 followers https://t.co/FVfe2B0h3Q pos 0.6
# ('neg', 1.0)
# DTB WE LIVE https://t.co/1rkYJN5Sp5 neg 1.0
# ('neg', 1.0)
# RT @codytweetstoo: watch me murder all of the IT guys near me so my grandparents start asking me how to turn their router on again
#
# 7PM CST… neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# RT @MJB_TTV: You voted! Stay Strapped or Get Clapped because it's WARZONE time baby! Swing by and chat with me!! Then watch as I sail the s… neg 1.0
# ('neg', 1.0)
# Short GTA Stream:) #NorCalRC https://t.co/68mdNoDcJ6 neg 1.0
# ('neg', 1.0)
# S&amp;D  https://t.co/A9ZJfwhLD2 neg 1.0
# ('neg', 1.0)
# Tonight the stream returns with the playthrough of the campaign in @PistolWhipVR! My legs won't like me tomorrow bu… https://t.co/zz8LQvHWvX neg 1.0
# ('neg', 1.0)
# AAA Rollover - GHOSTS! https://t.co/rov7F2ffV6 neg 1.0
# ('neg', 0.7142857142857143)
# scared boy plays ghost game https://t.co/uRiDsuTFKy neg 0.6
# ('neg', 1.0)
# https://t.co/qj9USvMQkQ neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('pos', 0.7142857142857143)
# Lupa tá on, qual será o 7x1 de hoje? Cola na live pra conversar comigo: https://t.co/MrUaPJmbfR pos 1.0
# ('neg', 0.8571428571428571)
# RT @bigpaparafa: live neg 0.8
# ('neg', 1.0)
# RT @loud_victor: DEPOIS DE MUITO TEMPO, voltei kkkkkkk https://t.co/7MYHf6EeIF neg 1.0
# ('neg', 1.0)
# HAPPY MONDAY! HOW WE DOING https://t.co/D5SLUFzHjD neg 1.0
# ('pos', 0.5714285714285714)
# RT @HeavyOneWay: Estamos por comenzar con la winner final del torneo SLS 2
# @SekaiDoggo vs @zRiiKy
# Chile vs Mexico en nuestro stream de One… pos 0.6
# ('neg', 0.8571428571428571)
# Hello everyone! Early 7pm stream (Central time) playing some Monster Camp 2!
#
# I’m still recovering from a medical e… https://t.co/OiDVcuGqfh neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 1.0)
# RT @RivalsWaterdeep: Tomorrow at 10 am central is our weekly video game stream! Hitman will likely be on the menu again. If you have any ot… neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 1.0)
# RT @vKuaniTV: Facecam controller ranking https://t.co/hZD0E6kR5e neg 1.0
# ('neg', 0.5714285714285714)
# Mas vale tarde que nunca.
#
# https://t.co/TngQeoBzj7 pos 0.6
# ('neg', 1.0)
# Check out my broadcast from my PlayStation 4! #PS4live (Call of Duty®: Modern Warfare®)  live at https://t.co/024PFQSBhJ neg 1.0
# ('neg', 1.0)
# RT @analogjudas: JUDAS FEST LIVES THANK GOD STARTING HERE IN LIKE 20 MIN AND ALSO TWITCH https://t.co/6dfFddv7EB https://t.co/BC2AZaZbhp neg 1.0
# ('neg', 1.0)
# RT @banksy_311: 🔴LIVE
# Skinbet
# DatDrop
# Gamdom
#
# $15 Giveaway &amp; Slot Calls
#
# Like &amp; RT
# Be on stream: https://t.co/QwO1nWjFMy https://t.co/33MlW… neg 1.0
# ('neg', 1.0)
# Horror game + Heart Rate Monitor?
# https://t.co/XxtaEwKeu9
# Starting at 5pm PST neg 1.0
# ('neg', 1.0)
# RT @GreatGatsbySSB: TOOM #4 tourney run https://t.co/8D3xKamhJ7 neg 1.0
# ('neg', 0.8571428571428571)
# RT @phyerx: LIVE NOW *:･ﾟ✧♡ @LANLordsGaming
# https://t.co/h4pTAn0uHM neg 0.8
# ('neg', 1.0)
# not streaming the combine so join @ToXsiK stream if you wanna watch me hoop ⬇️ neg 1.0
# ('neg', 1.0)
# Lots of combine watch parties tonight, don't miss @BlkFrankWhite1 and I on the @NBA2KLeague Twitch channel at 9 pm/… https://t.co/zhmrsKDCva neg 1.0
# ('pos', 0.7142857142857143)
# RT @pPersie_: We hit 600 on twitch and 200 on twitter today! The fuck! You guys are amazing and I couldn't have gotten to where I am withou… pos 1.0
# ('neg', 1.0)
# Playing pyre a few years too late cause this soundtrack is a bop!//getting SMASHED at league https://t.co/9RlXnvIWgy neg 1.0
# ('neg', 0.7142857142857143)
# RT @GiveawaySquadd: Book a giveaway promotion on my website @ https://t.co/U9q33rmKTF today &amp; grow by thousands of new followers on platfor… neg 0.8
# ('neg', 1.0)
# RT @poutinesmoothie: An eye twitch is just winking in Morse code. neg 1.0
# ('neg', 1.0)
# IRONS HARDER THAN CHALLENGER DONT @ ME | CLIMBING ONLY LUX/SENNA SUPPORT GAMEPLAY GOD https://t.co/RaK2uzQifI neg 1.0
# ('neg', 1.0)
# RT @funtimedanieI: I fr brought gogyWhip to twitch in fucking NOVEMBER and you fuckers make and entire hashtag and remove my emote? 💀 y'all… neg 1.0
# ('pos', 0.8571428571428571)
# streaming some @official_glp  🐻 grizzly 🐻 tourneys. Let’s get a trophy
#
# https://t.co/J9uL9lTadd https://t.co/BQ01Q4cj4D pos 1.0
# ('neg', 0.8571428571428571)
# COLD WARRR SZN live at https://t.co/fQejae4qsu neg 0.8
# ('neg', 1.0)
# RT @Justin911112: LIVE again wearing the chicken mask. Maybe we can confuse people and get some wins tonight @TeamDyre
# https://t.co/tKgR32… neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 1.0)
# RT @Trakz1k: can anyone join my stream https://t.co/41c5z5KL4v neg 1.0
# ('pos', 0.7142857142857143)
# RT @liljarviss: Gonna play Fortnite live on Twitch in 30 minutes!! Gotta be more careful this time.
#
# Sharing link in 30 minutes #FreeJarvis pos 1.0
# ('neg', 1.0)
# on 2k with the guyzas @WhiteeRicann @GabesALamo https://t.co/24zDLmOBX9 neg 1.0
# ('neg', 1.0)
# @locochoncin https://t.co/aJ6g2jAIbt neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# RT @mansuryavas06: Sevgili Pelin,
#
# İçeriklerin beni ve ailemi çok eğlendiriyor. Gençlerimizin pozitif enerjisi bizleri mutlu ediyor.
#
# Twitc… neg 1.0
# ('neg', 1.0)
# RT @maximilian_: STREAMING ON TWITCH! KILLER INSTINCT Twitch Rivals Tournament #BringBackKi (2-1) @KillerInstinct @Xbox @TwitchRivals @Xbox… neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 1.0)
# Making GFX Live $5 (YouTube ,Twitch,Twitter Banners &amp;  Wallpappers) https://t.co/NQyHpvc9QH neg 1.0
# ('neg', 1.0)
# [EN] Can I buy Gamestop Stonks now? | Gold Gameplay | DPS/Healer Main  | !discord https://t.co/NHbujOmLbO… https://t.co/Oq4FkWDanF neg 1.0
# ('neg', 1.0)
# RT @loud_victor: DEPOIS DE MUITO TEMPO, voltei kkkkkkk https://t.co/7MYHf6EeIF neg 1.0
# ('neg', 1.0)
# RT @FearFragr: Live now! w/@Vulixeee @tri_bune @PistoIPIay @o_Dimensionz
#
# https://t.co/xCgV9uld7I neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('pos', 0.7142857142857143)
# RT @Lc_retsnom: welp its been a awhile but uh yeah gonna chill and stream some GTA online, so why not come chill out with me?? https://t.co… pos 1.0
# ('neg', 1.0)
# RT @purzyo: Live now with the Gnome SMP! W @BigGnomey @Tkay_Gamez
#
# Watch Purzyo7 with me on Twitch! https://t.co/D2e8ALX1WI neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 1.0)
# Some twitch panels for a friend with backgrounds and no text because pretty uvu https://t.co/0wOzNH40kr neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# RT @Raidhn_GoW: AYOOOOOOOOOOOOOOOO ????????????
# https://t.co/gWAFEvsc3z neg 1.0
# ('neg', 1.0)
# RT @holdbacktoblock: We're excited to be a part of @maximilian_'s KI Lives event tonight! Keep watching the stream for more KI videos from… neg 1.0
# ('neg', 1.0)
# NOBODYS DYING TODAY (nuzelock) https://t.co/MfJZPTrCCe neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 1.0)
# Designing vinyls with my bros.  https://t.co/i79F19ua4t neg 1.0
# ('neg', 1.0)
# RT @TTVcm3TV: !FunkyFriday loadouts are up some MnK practice then controller I !loadouts !socials !au https://t.co/g4ecLroi29 neg 1.0
# ('neg', 1.0)
# @Twitch why isn’t @tornjordans partnered?
#
# Over 25,000 followers on twitch.
#
# Huge discord community of nearly 1,0… https://t.co/VaF88ByyLM neg 1.0
# ('neg', 0.5714285714285714)
# RT @MakeitBumpMusic: TONIGHT we are taking a trip down memory lane and we're gonna relive some of my FAVORITE virtual festival sets through… pos 0.6
# ('neg', 1.0)
# 59 Days https://t.co/mLrHMUpwgM neg 1.0
# ('neg', 0.5714285714285714)
# 😅 😅 😅Etiqueta a alguien que ele pase eso  almenos a mi si
# #twitch #streming #xbox #gamers #visitas #fbgamingvideos… https://t.co/x4ze1l4pLu pos 0.6
# ('neg', 0.8571428571428571)
# RT @TheNotoriousDT: Going live at 5:15 PM PST/ 8:15 PM PST!!!
#
# BEST MUSTACHE AND LOCK will be on 2k!!
#
# https://t.co/aDEt5upTLy neg 0.8
# ('neg', 1.0)
# Wait...w-where did Teeny go?! Who the hell is Rosa?!
# #RosaRomanotakesover
# https://t.co/zTJjYw72X8 neg 1.0
# ('pos', 0.5714285714285714)
# RT @FrigidFenix: Live Now!
#
# Have some new stuffs and ready to play some games with you all! Come hang out and lets have some fun!
#
# https://… pos 0.6
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 0.5714285714285714)
# RT @ikkiomu: ¡Hola pankus! ❤ En 20 minutos estaré con @F4F4VT una serie de Minecraft: VLAND ✨
#
# ¡Los espero ahí con muchas ansias!
#
# https:/… pos 0.6
# ('neg', 1.0)
# RT @Yuldyy: come watch https://t.co/HelIAFEAL4 neg 1.0
# ('neg', 1.0)
# RT @loud_victor: DEPOIS DE MUITO TEMPO, voltei kkkkkkk https://t.co/7MYHf6EeIF neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('neg', 1.0)
# RT @Kishtar: Viajemos al pasado! LE DAMOS A #MINECRAFT
# https://t.co/NgK3fWeVxz
#
# ✅YA EN VIVO https://t.co/5QrsiAeeUT neg 1.0
# ('neg', 0.8571428571428571)
# RT @bennyblancobx85: Going live in 3...2...1... https://t.co/ZIJukfWVEV #livestreaming #modernwarfare #cod #callofdutymodernwarfare @Illest… neg 0.8
# ('neg', 0.5714285714285714)
# RT @MYMALK4PON3: Les dejo una guía útil para reportar un canal, de esta manera Twitch pone atención más rápido al problema. Al pedir que re… pos 0.6
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# RT @McCoySonza: But like do I have a chill stream or have a typical McCoy sweaty one ya know? @AspireGamingNA https://t.co/XAwqveaaGR neg 1.0
# ('pos', 0.7142857142857143)
# RT @pogbursoot: @pandastwtt @gamergirlkarl my brother's gf!! she's really sweet &amp; is bi :)
# https://t.co/gNauYmFOyO pos 1.0
# ('neg', 1.0)
# Monday Night Frights (The Letter)
# https://t.co/VZxPJTO1Fp neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('neg', 1.0)
# New emote is up! I need feedback like I need this shiny Lugia! We gonna get spicy tonight!???  https://t.co/IUwCukkLIt neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 0.8571428571428571)
# 👾promotion time👾
#
# 1. Like / Retweet
# 2. Comment your YT/twitch
# 3. Follow me / Sub To My Channel in bio
# 4. GROW TOG… https://t.co/hBLwJxmZTh neg 1.0
# ('neg', 1.0)
# Fire Emblem Echoes: Panumbras of Valentines https://t.co/IWvKuEW41i neg 1.0
# ('pos', 0.7142857142857143)
# RT @cachoo01: Si me toca TOTY en el directo de hoy sorteo 12.000 Fifa Points entre todos los que den RT y me sigan!!!
#
# Suerte a todos!! 🍀🍀… pos 1.0
# ('neg', 0.8571428571428571)
# RT @nesstolgia: Time to see if our girl can become the gold digger she was born to become in #thesims3 lol Feel free to stop by and hang ou… neg 1.0
# ('neg', 0.5714285714285714)
# RT @elohimmusic: IM OFFICIALLY ON TWITCH. my first stream will be this Wed 3pm pst, the beginning of a series called “music is medicine”. E… neg 0.6
# ('neg', 0.5714285714285714)
# I’ve been vibin and streaming lately! I’m affiliated on twitch! Show some love and support. Warning ⚠️ the boys and… https://t.co/RaWQNF4yed neg 0.6
# ('neg', 0.8571428571428571)
# Why should I stream on Twitch, if I get buried at the very bottom of the stack. The likelihood of being noticed is… https://t.co/Set9CtSuEm neg 1.0
# ('neg', 0.5714285714285714)
# RT @WookieThrows: When you've never seen anyone actually pull a Charizard, but you get it in your first packs in years 🔥 https://t.co/Xaswl… neg 0.6
# ('neg', 0.5714285714285714)
# Back and trying to make sure my stuff still works after my break from streaming and gaming #twitch #twitchtv… https://t.co/VCsAbYlOLX neg 0.6
# ('neg', 1.0)
# RT @BrunkDrody: Join the Brunk Brigade and redeem your stupid Points! Chat redeemed hydration and push-ups with the goal of making me puke!… neg 1.0
# ('neg', 1.0)
# RT @loud_victor: DEPOIS DE MUITO TEMPO, voltei kkkkkkk https://t.co/7MYHf6EeIF neg 1.0
# ('neg', 1.0)
# RT @PhillupJFryy: WERE BACK BABY! GRINDING VAL!
#
# RTS AND LURKS APPRECIATED!
#
# @DelusionDN
#
# #UVSZN #UVPhilly
#
# https://t.co/92lPpZKDlp
# https:… neg 1.0
# ('neg', 1.0)
# صبح صبح https://t.co/4luK39rkJm neg 1.0
# ('neg', 0.8571428571428571)
# Aaaand we’re live https://t.co/ACjC24H6Cg neg 0.8
# ('pos', 0.8571428571428571)
# ok its a twitch stream but its me drunkenly listening to the ska album we released in high school and haven't liste… https://t.co/B1RwaH0uJi pos 1.0
# ('neg', 1.0)
# Streaming Right Now! https://t.co/2oM7iF5x9y neg 1.0
# ('neg', 0.8571428571428571)
# Drop book wrong side up at spawn point and HUNT STARTS
#
# Most terrifying 50 seconds of my life trying to outrun a gh… https://t.co/rJTREnIdJG neg 1.0
# ('neg', 1.0)
# Só gente brava!! Essa semana será incrível!!! neg 1.0
# ('neg', 1.0)
# RT @YoSoyRickYT: 👉🥳   SORTEOOOOOOOOOOO 😱🤑🤑🤑
#
# 👀🔥5 TARJETAS DE $100
#
# REQUISITOS:
#
# -SEGUIRME EN TWITCH: https://t.co/DL1zD5jzZo
#
# -SUSCRIBIRTE… neg 1.0
# ('neg', 1.0)
# RT @loud_victor: DEPOIS DE MUITO TEMPO, voltei kkkkkkk https://t.co/7MYHf6EeIF neg 1.0
# ('neg', 0.8571428571428571)
# I’ve just been religiously watching youtube and twitch these past few months I don’t remember what it’s like to watch an actual tv show neg 1.0
# ('neg', 1.0)
# Chill Valorant Solo Queue  https://t.co/mziN195E6E neg 1.0
# ('neg', 1.0)
# RT @loud_victor: DEPOIS DE MUITO TEMPO, voltei kkkkkkk https://t.co/7MYHf6EeIF neg 1.0
# ('neg', 1.0)
# RT @ToXsiK: .@NBA2KLeague COMBINE!
#
# https://t.co/k1k46WqOyf neg 1.0
# ('neg', 0.7142857142857143)
# I’m playing Minecraft on stream right now! https://t.co/sO4vXXg6id neg 0.8
# ('neg', 1.0)
# Doing a FT5 Money Match on stream!
#
# COME WATCH https://t.co/86yjHUO3yd neg 1.0
# ('neg', 0.5714285714285714)
# Wow good luck neg 0.6
# ('neg', 1.0)
# RT @PatrickAdemo: Pour ceux qui s'font chier
#
# https://t.co/k6kYrqiv4R neg 1.0
# ('neg', 0.8571428571428571)
# RT @TutosBS: Y twitch aun no me aprueba los emotes
#
# https://t.co/Mcnq35vCnq neg 0.8
# ('neg', 1.0)
# Monster Monday - Alseid https://t.co/fKYBDk87cs neg 1.0
# ('neg', 1.0)
# Playing Solo on Apex Legends Tonight.                Come Hangout!  https://t.co/Z6wvYagSmf neg 1.0
# ('neg', 1.0)
# RT @kwehzy: Playing Raft with peeps before Among Us tonight! https://t.co/K7GCKyVbJ3 neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 0.8571428571428571)
# RT @Englefield5_: 1v4 Clutch live on stream !!! 😍
#
# #youtubegaming #warzone #twitch #gaming #ps5 #CallofDuty #stream
#
# https://t.co/fQ4NDSKe… neg 0.8
# ('neg', 1.0)
# RT @discotekmedia: The premiere of the English dub of Memories is this Saturday, February 6th at 9PM Eastern/6PM Pacific.
#
# Stay after the p… neg 1.0
# ('pos', 0.7142857142857143)
# RT @Alcatras667: Directo de 1 hora 😮 Directo de 1 hora 😮
# https://t.co/vSlL2c2LYe
# RT y me quedo 1 minuto mas pos 1.0
# ('neg', 1.0)
# Well look at the time its Tomb Raider O' Clock. Playing that rise of the Tomb Raider again. Should be nearing the e… https://t.co/dtNUtHL48u neg 1.0
# ('pos', 0.5714285714285714)
# @TwitchBR Minha namorada queria me assustar jogando Resident evil... CONSEGUIU https://t.co/cDRYvmPf9u https://t.co/NSsosA1uWk pos 0.6
# ('neg', 1.0)
# RT @Bexohs: I'M LIVE :)
#
# https://t.co/HWBewRyd4v neg 1.0
# ('pos', 0.5714285714285714)
# Livezinha on
# Cola para jogar um lobbyzinha❤
#
# https://t.co/feJCZFgFlf pos 0.8
# ('neg', 1.0)
# RT @tybri: Rolling Loudddddd💅🏽💕 neg 1.0
# ('neg', 1.0)
# JOINN TF UP  !socials !donate https://t.co/nPDG339c33 neg 1.0
# ('neg', 0.8571428571428571)
# weest is live! https://t.co/5MQKJ9E3UK neg 0.8
# ('neg', 1.0)
# RT @loud_victor: DEPOIS DE MUITO TEMPO, voltei kkkkkkk https://t.co/7MYHf6EeIF neg 1.0
# ('neg', 0.8571428571428571)
# RT @ArwenSharpReads: I am braver then I think I am....   |18+|
# ☕☕ MUG full of HUGS ☕☕🥔🥔#PotatoAimersSquad https://t.co/Y66bJuwZM5 neg 0.8
# ('neg', 0.7142857142857143)
# RT @jontinpaul: Going live at 6:40 PM EST to celebrate my birthday with, @blizzb3ar =D Come watch us  recreate the plot of Brokeback Mounta… neg 0.6
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# RT @carolynmichelle: Blistering arcade action! neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 0.5714285714285714)
# RT @SmallStreamersC: We're hosting therealchubbs52 playing #FarmingSimulator19 with 29 viewers on Twitch! Be sure to show them some support… neg 0.6
# ('pos', 0.7142857142857143)
# RT @liljarviss: Gonna play Fortnite live on Twitch in 30 minutes!! Gotta be more careful this time.
#
# Sharing link in 30 minutes #FreeJarvis pos 1.0
# ('neg', 1.0)
# STARTING NOW neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# Watch theprincesaiyan1 with me on Twitch! https://t.co/1Iu4c1kBN0 neg 1.0
# ('neg', 1.0)
# I'm live playing some Isaac runs, come watch and chat type pog in my chat - https://t.co/5KsTqvJOrP neg 1.0
# ('neg', 1.0)
# A little over an hour to go! neg 1.0
# ('neg', 1.0)
# Stream ON!!
#
# https://t.co/A4s8HnoS9s neg 1.0
# ('neg', 0.5714285714285714)
# Top Morgana EU (rankeds) [ESP/ENG] 2.02 https://t.co/68tFlDrdBq
#
# Mi colega con morgana, ¡echadle un ojo! pos 0.6
# ('neg', 1.0)
# RT @Dirk_JDR: WE LIVEEEEEEEEEEEEEE
#
# NBA 2K LEAGUE COMBINE WATCH PARTY WITH SOMEONE WHO COMMENTATES THE NBA 2K LEAGUE
#
# https://t.co/X2lKOPUo… neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 1.0)
# minecraft smp #3 in vr https://t.co/v2Pdonbf3W neg 1.0
# ('neg', 0.5714285714285714)
# Doing my first playthrough of SYNTHETIK, come on by and watch! https://t.co/l90NuG7nnx neg 0.6
# ('pos', 0.7142857142857143)
# 🔴¡EN DIRECTO!
#
# Estamos haciendo cosas Chulhus!! 🙃🎨
#
# ¡¡Anímate y pasa a saludar!! 🐙🥝
# https://t.co/4uZGZ8q99v pos 1.0
# ('pos', 0.7142857142857143)
# RT @barcagameryt: MI PRIMER MILLÓN!!! 🥳🥳
#
# Muchas gracias a los que me siguieron desde que inicié y a los que apenas me siguen. Me hace much… pos 1.0
# ('neg', 1.0)
# ,🔴 LIVE! Doing more pirate stuff!! https://t.co/NaAg16OyPr @SavanaHume https://t.co/mbn1KHuk1l #TwitchStreamers… https://t.co/JZCZApPOkm neg 1.0
# ('neg', 1.0)
# dog im crying https://t.co/IfaWGMTq0G neg 1.0
# ('pos', 0.7142857142857143)
# RT @cachoo01: Si me toca TOTY en el directo de hoy sorteo 12.000 Fifa Points entre todos los que den RT y me sigan!!!
#
# Suerte a todos!! 🍀🍀… pos 1.0
# ('neg', 0.8571428571428571)
# Running with the squad, cover your ears kids.   | @NFeKToGaming | https://t.co/S8s7qdERsM neg 0.8
# ('neg', 1.0)
# RT @DrunkenUncle_: AAA Rollover - GHOSTS! https://t.co/rov7F2ffV6 neg 1.0
# ('pos', 0.7142857142857143)
# RT @cachoo01: Si me toca TOTY en el directo de hoy sorteo 12.000 Fifa Points entre todos los que den RT y me sigan!!!
#
# Suerte a todos!! 🍀🍀… pos 1.0
# ('neg', 1.0)
# Get in here!!!! We playing some VALORANT.
#
# #Streamerforthepeople #Twitchtv #smallstreamer #smallstreamercommunity
# https://t.co/SV2QMxqKOz neg 1.0
# ('neg', 1.0)
# Check out my broadcast from my PlayStation 4! #PS4live (Call of Duty®: Modern Warfare®)  live at https://t.co/VwfzY3tHCv neg 1.0
# ('neg', 1.0)
# We are now LIVE on twitch for some Stone block ! So if you want to rock, you can come at https://t.co/QzV4TTvssF  (… https://t.co/wBZZGe6vJK neg 1.0
# ('neg', 1.0)
# @locochoncin https://t.co/PhFIBzZ2wy neg 1.0
# ('neg', 1.0)
# RT @KraQz7: Live! $40 Wager mit @_Sparkley https://t.co/haIbBBP8WP neg 1.0
# ('neg', 1.0)
# RT @Thorwyvern: Playing Some Assassin Creed Valhalla https://t.co/vFJTw1vSUU @AimersSquad neg 1.0
# ('pos', 0.8571428571428571)
# Shout-out to everyone who helped choose what to play for tonight’s stream!
#
# So for tonight,  I’ll be doing a dual… https://t.co/GH1lTdtmKF pos 1.0
# ('neg', 1.0)
# This isn't amateur hour! I'm still crushing some Call of Duty: Warzone.
# https://t.co/KIg5xv2xan neg 1.0
# ('neg', 0.8571428571428571)
# Uykusuz solo wz
#
# https://t.co/kxFFPeXpIq neg 0.8
# ('neg', 1.0)
# RT @PredatorJPN: 🎉1/30 (土) から開幕🎉
#
#  PUBG JAPAN CHALLENGEを応援してくれる方へ抽選で2名様に🎁！2Go ＃PJC
#
# @PUBGEsports_JP
# @PredatorJPN
# @predator_bear
# をフォロー &amp; RT… neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# RT @m4rs_b4r: hello!! im mars, im 15 and i'm a twitch streamer! onstream i play minecraft, grimms hollow, fnaf, cs and valorant !! my strea… neg 1.0
# ('neg', 1.0)
# check me on twitch, almost at affiliate! last day of season 7 #apex #apexlegends #streaming #gamergirl #twitch neg 1.0
# ('neg', 1.0)
# Playing some #DeadbyDaylight and trying to get to Rank 1. Come cheer me on!
#
# https://t.co/b2TwmJOzl4
#
# #twitchstream… https://t.co/mrskokg1K5 neg 1.0
# ('neg', 1.0)
# @Greedy_Gator . . .
#
# Strangely enough, Twitch highly doubts that!
#
# Still, he went ahead &amp; popped the marker's tip o… https://t.co/s37jvyT7d5 neg 1.0
# ('neg', 0.8571428571428571)
# End Of Week Stuff ! Opening Great Vaults / Torghast / M+ &amp; PERHAPS Heroic Sire D - Depends on Interest From Chat https://t.co/w6JqCLSrK4 neg 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 0.8571428571428571)
# Just went live! https://t.co/FW8Loc35Sr neg 0.8
# ('neg', 1.0)
# RT @ItsHydra_Art: I've wanted to make an emote for my twitch channel for a while.  Going for hydraParaSmug.  Like any one over the others?… neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 0.5714285714285714)
# RT @NesterNat9: @davidmweissman @kylegriffin1 @AOC I watched her Twitch talk and saw it on her face. I can’t even imagine how it was/is for… neg 0.6
# ('neg', 1.0)
# Going Live Soon and Something New to show off https://t.co/sbNWVfG3pF neg 1.0
# ('neg', 1.0)
# RT @pandadosgames: I'm now streaming on Twitch! Playing The Elder Scrolls Online https://t.co/y0O8tA7akT neg 1.0
# ('neg', 1.0)
# Chasing 30s Dropping 20s! ----------------125+ wins in warzone Let's Get it!  #warzone #callofdutymw #codwarzone… https://t.co/HiyPwFKozf neg 1.0
# ('pos', 0.7142857142857143)
# RT @jkaymeow: LIVE NOW - We're starting stream by french braiding my hair. I don't make the rules idk ~ I'm Sorry Mario, But Your Princess… pos 1.0
# ('neg', 0.8571428571428571)
# BEST AGGRESSIVE SNIPER IN THE WORLD #vL #VizuaLizeTheFuture #Enko #FaZeScp  live at https://t.co/cBkM4A5MsD neg 0.8
# ('neg', 1.0)
# @HBKfoghig or @kanavr_ ? Which VA homie should I root more for? https://t.co/VB8j10Z2Rs neg 1.0
# ('neg', 1.0)
# Gonna #stream #valorant on #twitch in about 5-10 min I think, waiting on friends
#
# 20ish more followers until I qual… https://t.co/4H3akviDKm neg 1.0
# ('neg', 0.8571428571428571)
# RT @AsiaMPL: How much trouble will I get in when we find the cult? Will I finally find love? How many more men will i kill? Find out tonigh… neg 1.0
# ('neg', 1.0)
# AMEM NE
# achei q tinha morrido neg 1.0
# ('neg', 0.7142857142857143)
# RT @_Jazzyguns: So my wifi is completely knocked out due to the Snowstorm in my area, so I won’t be able to stream tonight 🙃
# Currently usin… neg 0.8
# ('pos', 0.8571428571428571)
# Warzone by my lonely live at https://t.co/4NwT9udcqJ pos 1.0
# ('neg', 0.8571428571428571)
# Lofi IDM Beats / VCV Rack / Live 🌴🎧 https://t.co/tSDpLFVUek a través de @YouTube #filmcore #dubstep #dub #idm #edm… https://t.co/kEvh92dCXd neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('pos', 0.7142857142857143)
# Hey JR Spartan is live!!
# Stop by and show some love &amp; support
#
# https://t.co/ROBsJQddZi
#
# #twitchaffiliate… https://t.co/ChYrERj7Bw pos 1.0
# ('neg', 0.8571428571428571)
# Gonna chat for a bit then I'm playing #Minecraft kinda did a jog through. See how well we can do and just have a go… https://t.co/VdpfBpRSAB neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# ...
# ('neg', 1.0)
# RT @loud_victor: DEPOIS DE MUITO TEMPO, voltei kkkkkkk https://t.co/7MYHf6EeIF neg 1.0
# ('pos', 0.7142857142857143)
# RT @KojisanYT: Se juegan el liderato del grupo en #NTWorlds de @NoTiltGG entre las selecciones de @SeleccionCRmx y @Sel_Costa_Rica Todo por… pos 1.0
# ('neg', 1.0)
# Beginning A New on The Land Below. New Cult who Dis?  https://t.co/XdKC2Isw08 neg 1.0
# ('neg', 1.0)
# RT @JuanesPapeeh: Se llega a 48 horas??? RT RT https://t.co/D0vT3BLdug neg 1.0
# ('neg', 0.5714285714285714)
# RT @MAJIM190x: Gente directo en unos 20 minutos. Tengo un par de cosas que informarles u.u, que espero que resuelvan un par de dudas
#
# http… pos 0.6
# ('pos', 0.7142857142857143)
# RT @Clausinho10: https://t.co/a7ueGB3xOw
# Doble Mejor 83+
# Conclusión Evento #TOTY
# Mercado y Tradeos pos 1.0
# ('neg', 1.0)
# Live with the #AlphabetChallenge Game Z Reveal! It's between:
# - Zero Escape: Nine Hours, Nine Persons, 9 Doors
# - Zo… https://t.co/hEvyB0xnpW neg 1.0
# ('neg', 1.0)
# RT @MYMALK4PON3: Buena descripción! Lets go! https://t.co/v5vnHCd2V0 neg 1.0
# ('pos', 0.5714285714285714)
# RT @gfalconpunch: Oh hell yeah its time to get to work myself @Roze_Robotnik  , @ferro_streamer , @DragoFireBloom7  are going live right no… pos 0.6
# ('pos', 0.7142857142857143)
# RT @KojisanYT: Se juegan el liderato del grupo en #NTWorlds de @NoTiltGG entre las selecciones de @SeleccionCRmx y @Sel_Costa_Rica Todo por… pos 1.0
# ('neg', 1.0)
# RT @AerithReborn: https://t.co/sdabCUrEr4
#
# 2/2
#
# So if you want Pokemon packs, hit me up in DMs or my pokemon trainer in crime @MariYume_ 😎 neg 1.0
# ('neg', 1.0)
# RT @PandaGangFans: HAPPY MONDAYY✨
#
# Mon Feb. 1st:
# 1:30pm - The Day Stream with Daddy Panda 🐼🎮
#
# 5:30pm - MURKED! 🐼🔪
#
# https://t.co/HHMLHImaIv neg 1.0
# ('neg', 1.0)
# Griechischer Wein komm in den Stream hinein https://t.co/XSN0hODJ7p neg 1.0
# ('neg', 1.0)
# RT @NikeHoodii: Around 8 est I'll be streaming the combine tonight
#
# https://t.co/tkDCTvbC7g neg 1.0
# ('neg', 1.0)
# @liljarviss https://t.co/azXrksKQtE neg 1.0
# ('neg', 1.0)
# @eopdev @rtsmallstreams @BlazedRTs @PromoteAMGamers @SupStreamers @promo_streams Hi there! I am a chef, dad, fps ga… https://t.co/kIKzNNfXZi neg 1.0
# ('neg', 0.7142857142857143)
# RT @isadoraslvr: Confira OLHA QUEM VOLTOU não ta morto quem ta vivo - !comandos !lojinha https://t.co/i8K6PNr6KS neg 0.6
# ('neg', 0.8571428571428571)
# RT @AnaxEsports_: She live! neg 0.8
# ('neg', 1.0)
# Can you guys do me a favour and go follow my twitch racoonman271  and my YouTube Darth hazza. I would really appreciate it neg 1.0
# ('neg', 1.0)
# Boraaa gatxss
# SIGA SANDER JOGA neg 1.0
# ('neg', 1.0)
# @KoolGoody @BlazedRTs @sme_rt @FMC_RTs @rtsmallstreams @SupStreamers @promo_streams https://t.co/uQ95Z6J8i8 neg 1.0
# ('neg', 1.0)
# RT @ajk757: Guys the countdown to #BirthdayStream is on!! I can’t wait to spend all day Friday with you! Swipe through to check out the #gi… neg 1.0
# ('neg', 1.0)
# RT @GuiltyTalon: https://t.co/tCcEfSid7F
# noite neg 1.0
# ('pos', 0.7142857142857143)
# Back to the #FFXIV Grind!
#
# https://t.co/elteVQOFil
#
# Tonight we are starting off with some daily roulettes to try a… https://t.co/lgdktlOYtk pos 1.0
# ('neg', 1.0)
# @TheMattBongiovi Gamer on twitch 😬 neg 1.0
# ('neg', 1.0)
# RT @EB7: EN VIVO!!
#
# LA @NoTiltGG WORLDS CON @KojisanYT
#
# EMPIEZA EL PARTIDO DE MEXICO!! MEXICO vs COSTA RICA YA!!!
#
# HOY SOMOS TODOS EL TRI!… neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# BOT NELLY REPORTING FOR DUTY | 🖤 !discord https://t.co/QgCgPBNhjq neg 1.0
# ('neg', 1.0)
# I DID NOT SELL MY SOUL neg 1.0
# ('neg', 1.0)
# RT @SELDUM_: WILL BE STREAMING THE @NBA2KLeague COMBINE TONIGHT COME WATCH OUR TEAM FOR P5
#
# PG: @SELDUM_
# SG: @CALlRAQ
# SF: @MRoach954
# PF:… neg 1.0
# ('neg', 1.0)
# RT @damedashx: LIVE NOW &amp; Close to Affiliate! Please come lurk and hang to help get there @ https://t.co/98AfeTFkbX
#
# #PathToAffiliate #smal… neg 1.0
# ('neg', 1.0)
# RT @emzberri: SMALL STREAMERS!!!!!
#
# these tweets have worked out amazingly before so here's another one!!!
#
# drop your twitch links below an… neg 1.0
# ('neg', 1.0)
# RT @p3Tty_vall: Come watch my try and carry my duos partner
# https://t.co/BnsoTGzFUa neg 1.0
# ('neg', 0.5714285714285714)
# Dando uns tiros pra aquecer o cérebro! https://t.co/AwBDmZX45O pos 0.6
# ('neg', 1.0)
# @Jashlem @iluisalmeron LOS LEALES QUE VENIMOS DE TWITCH 💖 neg 1.0
# ('pos', 0.8571428571428571)
# RT @KingslayerNet: LIVE NOW! Come join the fun! Show some love &amp; support: Drop a like, subscribe, &amp; follow!
#
# #livestream #supportsmallstrea… pos 1.0
# ('neg', 1.0)
# Pokemon Starter Tier List! After, some Rust! Come say hi! | Day 39 #twitch #youtube #twitchaffiliate #smallstreamer… https://t.co/NcUX4VtEpZ neg 1.0
# ('neg', 1.0)
# CRACK SHACK CREW BATTLE FT. ZUPPY, JUSTUS, FAUST, GISM, DOPE, TRAVIOLI, MONO, AND MORE. Winning team gets $50 https://t.co/QmRLoDi0A3 neg 1.0
# ('neg', 1.0)
# 2 and Half Hitmen w/ Lauren &amp; Charlie  - Hitman 3 Gameplay https://t.co/AuSvqQKWdQ neg 1.0
# ('neg', 0.7142857142857143)
# Gotta say! The more people I see thirsting over Lady Dumitrescu the more I channel Pat's response to her popularity… https://t.co/g294OAyLt9 neg 0.6
# ('neg', 0.8571428571428571)
# Heroic Sire Denathrius will DIE tonight!!!! / Let's GO!!!! https://t.co/90gzamV1tc neg 1.0
# ('pos', 0.7142857142857143)
# RT @cachoo01: Si me toca TOTY en el directo de hoy sorteo 12.000 Fifa Points entre todos los que den RT y me sigan!!!
#
# Suerte a todos!! 🍀🍀… pos 1.0
# ('pos', 0.7142857142857143)
# RT @KojisanYT: Se juegan el liderato del grupo en #NTWorlds de @NoTiltGG entre las selecciones de @SeleccionCRmx y @Sel_Costa_Rica Todo por… pos 1.0
# ('neg', 0.5714285714285714)
# RT @IbaiLlanos: Empecé a stremear el 5 de febrero de 2020
#
# Hoy 2 de febrero de 2021 hemos superado los 5 millones de seguidores en Twitch… pos 0.6
# ('neg', 1.0)
# hey i might do a drawing stream on twitch this friday/saturday evening (my timezone is cet) to power through a dead… https://t.co/lAL1OIQd6e neg 1.0
# ('neg', 1.0)
# ESTE ES EL STREAM DEL MES Y VENGO PARA SALUDARLOS UN RATO! CORRELE Y NO TE PIERDAS EL TUYO
# https://t.co/4n2PzBswb7 neg 1.0
# ('neg', 1.0)
# @Nervarieno meanwhile:
# https://t.co/gDvNNLJC1j neg 1.0
# ('neg', 1.0)
# poor league gameplay https://t.co/KCmimq4Diw neg 1.0
# ('neg', 1.0)
# おはようー！
#
# ねむねむですが、このまま寝ていると夜に眠れなくなり、夜に駆けることになりそうなのでなんとか起きるぞい！
#
# 今日は21:00からTwitchで風花雪月！
#
# #おはよう neg 1.0
# ('neg', 1.0)
# patrão on
# https://t.co/51tOUNdVlX neg 1.0
# ('neg', 1.0)
# EN 10 MINUTOS DIRECTO PARA ALCANZAR EL AFILIADO, NECESITO LA MEDIA XFAVOR MUTIS APOYENME :( https://t.co/shVpKeM7GY neg 1.0
# ('pos', 0.7142857142857143)
# RT @KojisanYT: Se juegan el liderato del grupo en #NTWorlds de @NoTiltGG entre las selecciones de @SeleccionCRmx y @Sel_Costa_Rica Todo por… pos 1.0
# ('neg', 1.0)
# Live now! More Ikenfell starts in 10 minutes, but come file in and get comfy while the snow comes down here! neg 1.0
# ('neg', 1.0)
# WE LIVE! Come say hi !glasses
# https://t.co/SBtjl9r5Is
# https://t.co/SBtjl9r5Is https://t.co/wdlnLuw8Qj neg 1.0
# ('neg', 1.0)
# RT @Burt_Macklind: Pokemon Starter Tier List! After, some Rust! Come say hi! | Day 39 #twitch #youtube #twitchaffiliate #smallstreamer #pok… neg 1.0
# ('neg', 1.0)
# vibing https://t.co/9mYvT1SwXw neg 1.0
# ('neg', 1.0)
# Playing some Fall Guys: Ultimate Knockout. Let's go!
# https://t.co/d4050ivybp neg 1.0
# ('neg', 1.0)
# RT @sadiebunni: goals tweet for february!
# twitch followers - 140
# youtube subs - 30
# please help exposure by liking and rting it really means… neg 1.0
# ('pos', 0.5714285714285714)
# ¡Mira la transmisión de mi PlayStation 4! #PS4live (Fortnite)  live at https://t.co/77KUeD51Yy pos 0.8
# ('neg', 0.8571428571428571)
# Still live and playing League of Legends. Get in here.
# https://t.co/32qXWkTKHW neg 0.8
# ('neg', 0.7142857142857143)
# É pra glorificar de pé igreja!!!! Skksksksksk neg 0.6
# ('neg', 0.8571428571428571)
# bati 101.615 no @aimlab em live e só percebi minutos depois kkkkkkkkkkk
#
# https://t.co/QZDLhQtOWy 😳 https://t.co/YgJsvHRCCC neg 0.8
# ('neg', 1.0)
# TWITCH in ten min!!! https://t.co/NOlRZnkqfz https://t.co/T9bP8cue4d neg 1.0
# ('pos', 0.7142857142857143)
# RT @KojisanYT: Se juegan el liderato del grupo en #NTWorlds de @NoTiltGG entre las selecciones de @SeleccionCRmx y @Sel_Costa_Rica Todo por… pos 1.0
# ('neg', 1.0)
# RT @HallowAU: 🔴HALLOW US LIVE🔴
# Playing #battlefront2 today!!
# Subathon is still going!! Use !subathon in chat ❤
# Come hang with me!!
# @TeamT… neg 1.0
# ('pos', 0.8571428571428571)
# Swing by and show @labattz some love for this great cause. I'll be in there cheering Nolan on pos 1.0
# ('pos', 0.8571428571428571)
# RT @AmaJustito: Feb First full of fun | New Among Us YT vid out| Smash Ultimate then Streaming Among Us post 10pm https://t.co/swFzPTRjiY pos 1.0
# ('neg', 1.0)
# Ele Shaman Mythic+ trying to push https://t.co/Po0hDKbGsV neg 1.0
# ('neg', 1.0)
# RT @o0oSocko0o: Goofing off with friends!!!  https://t.co/KEobC94TK2 neg 1.0
# ('neg', 1.0)
# RT @zyphiria: BIG Kiss From Father Zyphiria!! 💋
#
# #Twitch #SmallStreamerCommunity #Twitchfails https://t.co/oOLjZ6T2oi neg 1.0
# ('neg', 1.0)
# RT @zyphiria: BIG Kiss From Father Zyphiria!! 💋
#
# #Twitch #SmallStreamerCommunity #Twitchfails https://t.co/oOLjZ6T2oi neg 1.0
# ('neg', 1.0)
# RT @filipeeFN: @liljarviss https://t.co/azXrksKQtE neg 1.0
# ('neg', 0.7142857142857143)
# Estrenamos también canal de Twitch… https://t.co/PahuCjqQCk neg 0.6
# ('neg', 1.0)
# Ville det vært interessant med norsk karrieremodus på Youtube og eller Twitch? neg 1.0
# ('pos', 0.8571428571428571)
# RT @sistermaryjvne: Official DJ schedule Mondays, Wednesday’s and Fridays @ 8pm! I’ll see tn @ 8 :))) https://t.co/YxQvPWaHxM https://t.co/… pos 1.0
# ('neg', 1.0)
# RT @YurikaCarol: STREAM ON
# JOGANDO COM OS MANAGERS DE VALORANT DESSE BRASIL
#
# https://t.co/8tMLppexxv
#
# RT = vai receber noticia boa hein ht… neg 1.0
# ('neg', 0.8571428571428571)
# RT @DBFig: Going live with FF14. LET'S GO!
#
# https://t.co/iigscibjJJ
#
# #twitch #FFXIV neg 0.8
# ('neg', 1.0)
# Did my first my team stream on nba 2k21 that was a complete success last night on twitch ! Wanna thank everyone tha… https://t.co/x4Ba1AxcpV neg 1.0
# ('neg', 1.0)
# Check out Overwatch! Road To Affiliate! | Giveaway At 50!!  https://t.co/mo3OaGA0Nh neg 1.0
# ('neg', 0.8571428571428571)
# RT @liljarviss: Twitch is banned so YouTube link in the  next tweet. No facecam this time so good luck banning me Epic. neg 1.0
# ('neg', 1.0)
# @AlexaDalton6 @rtsmallstreams @promo_streams @sme_rt @SupStreamers @stream_caster @SupportStreamz @Rapid__RTs… https://t.co/EJN9THmLcg neg 1.0
# ('neg', 1.0)
# Fellow Gamers! Check out Snowed in with Crunch-Time!! 🎮❄️☃️ https://t.co/Yxs6FN5uvV neg 1.0
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     591                 if len(mvb) <= chunk_left:
# --> 592                     n = self._safe_readinto(mvb)
#     593                     self.chunk_left = chunk_left - n
#
# ~\anaconda3\lib\http\client.py in _safe_readinto(self, b)
#     621         if n < amt:
# --> 622             raise IncompleteRead(bytes(b[:n]), amt-n)
#     623         return n
#
# IncompleteRead: IncompleteRead(0 bytes read, 512 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     435             try:
# --> 436                 yield
#     437
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     517                 cache_content = False
# --> 518                 data = self._fp.read(amt) if not fp_closed else b""
#     519                 if (
#
# ~\anaconda3\lib\http\client.py in read(self, amt)
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#
# ~\anaconda3\lib\http\client.py in readinto(self, b)
#     491         if self.chunked:
# --> 492             return self._readinto_chunked(b)
#     493
#
# ~\anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     602         except IncompleteRead:
# --> 603             raise IncompleteRead(bytes(b[0:total_bytes]))
#     604
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-65-a4f47bb92cb7> in <module>
#      36
#      37 twitterStream = Stream(auth, listener())
# ---> 38 twitterStream.filter(track=search_words)
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     318             # call a handler first so that the exception can be logged.
#     319             self.listener.on_exception(exc_info[1])
# --> 320             six.reraise(*exc_info)
#     321
#     322     def _data(self, data):
#
# ~\anaconda3\lib\site-packages\six.py in reraise(tp, value, tb)
#     701             if value.__traceback__ is not tb:
#     702                 raise value.with_traceback(tb)
# --> 703             raise value
#     704         finally:
#     705             value = None
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     538                         # raised during streaming, so all calls with incorrect
#     539                         # Content-Length are caught.
# --> 540                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     541
#     542         if data:
#
# ~\anaconda3\lib\contextlib.py in __exit__(self, type, value, traceback)
#     129                 value = type()
#     130             try:
# --> 131                 self.gen.throw(type, value, traceback)
#     132             except StopIteration as exc:
#     133                 # Suppress StopIteration *unless* it's the same exception that
#
# ~\anaconda3\lib\site-packages\urllib3\response.py in _error_catcher(self)
#     452             except (HTTPException, SocketError) as e:
#     453                 # This includes IncompleteRead.
# --> 454                 raise ProtocolError("Connection broken: %r" % e, e)
#     455
#     456             # If no exception is thrown, we should avoid cleaning up
#
# ProtocolError: ('Connection broken: IncompleteRead(0 bytes read)', IncompleteRead(0 bytes read))

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import style
import time

style.use("ggplot")

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

def animate(i):
    pullData = open("twitter-out.txt","r").read()
    lines = pullData.split('\n')

    xar = []
    yar = []

    x = 0
    y = 0

    for l in lines[-200:]:
        x += 1
        if "pos" in l:
            y += 1
        elif "neg" in l:
            y -= 1

        xar.append(x)
        yar.append(y)
        
    ax1.clear()
    ax1.plot(xar,yar)

ani = animation.FuncAnimation(fig, animate, interval=1000)
plt.show()
